# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inpPath = "C:/CarolineZiegler/Studium_DCU/8. Semester/Data Analytics for Marketing Applications/Pair Assignments/"
demographics = pd.read_csv(inpPath + "demographics.csv", delimiter =  ",", header = 0)
demographics
# Out:
#      Age (in years)  CAO Points (100 to 600)  \
# 0              21.0                      NaN
# 1              22.0                    505.0
# 2              20.0                    600.0
# 3              19.0                    543.0
# 4               NaN                    407.0
# ..              ...                      ...
# 117            21.0                    565.0
# 118            20.0                    520.0
# 119            20.0                    510.0
# 120            23.0                    490.0
# 121            22.0                    500.0
#
#      Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                           10.0
# 1                                            NaN
# 2                                           30.0
# 3                                           10.0
# 4                                            8.0
# ..                                           ...
# 117                                          7.0
# 118                                          7.0
# 119                                         60.0
# 120                                          7.0
# 121                                          4.0
#
#      Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                                 66.0                4.0    Male
# 1                                 68.0                7.0  Female
# 2                                  NaN                6.0  Female
# 3                                 71.0                NaN    Male
# 4                                 73.0                1.0    Male
# ..                                 ...                ...     ...
# 117                               71.0                3.0  Female
# 118                               62.0                8.0  Female
# 119                               65.0                5.0    Male
# 120                               70.0                4.0  Female
# 121                               65.0                4.0  Female
#
#      Number of older siblings  Number of younger siblings  \
# 0                           0                           2
# 1                           0                           1
# 2                           1                           2
# 3                           0                           1
# 4                           2                           0
# ..                        ...                         ...
# 117                         2                           1
# 118                         0                           2
# 119                         1                           1
# 120                         0                           3
# 121                         0                           3
#
#      Old Dublin postcode (0 if outside Dublin)  Height (in cm)  \
# 0                                            0           178.0
# 1                                            0           155.0
# 2                                            0           180.0
# 3                                           13           187.0
# 4                                           15           181.0
# ..                                         ...             ...
# 117                                         14           170.0
# 118                                          7           165.0
# 119                                          0           184.0
# 120                                          7           173.0
# 121                                          0           177.0
#
#      Weight (in kg) Eye colour Hair colour  \
# 0              92.0      Green       Brown
# 1              55.0       Blue       Brown
# 2              55.0       Blue       Brown
# 3              76.0       Blue         Red
# 4              87.0       Blue       Brown
# ..              ...        ...         ...
# 117            59.0       Blue       Black
# 118            70.0       Blue       Black
# 119            85.0       Blue       Brown
# 120            73.0      Green      Blonde
# 121            73.0       Blue       Brown
#
#      Last 4 digits of your mobile (0000 to 9999)  Star sign  Shoe size
# 0                                           5262  Capricorn        9.0
# 1                                           7181        Leo        4.0
# 2                                           7677        Leo        5.0
# 3                                            838     Taurus        9.0
# 4                                           6290     Cancer        9.5
# ..                                           ...        ...        ...
# 117                                         1699      Libra        6.0
# 118                                         5289     Taurus        5.0
# 119                                         5317      Libra       10.0
# 120                                         4602   Aquarius        7.0
# 121                                         6402        Leo        7.0
#
# [122 rows x 16 columns]

# %%
demographics.isna().sum()
# Out:
# Age (in years)                                 1
# CAO Points (100 to 600)                        1
# Daily travel to DCU (in km, 0 if on-campus)    1
# Average year 1 exam result (as %)              1
# Seat row in class                              1
# Gender                                         0
# Number of older siblings                       0
# Number of younger siblings                     0
# Old Dublin postcode (0 if outside Dublin)      0
# Height (in cm)                                 0
# Weight (in kg)                                 0
# Eye colour                                     0
# Hair colour                                    0
# Last 4 digits of your mobile (0000 to 9999)    0
# Star sign                                      0
# Shoe size                                      0
# dtype: int64

# %%
round(demographics.describe(),2)
# Out:
#        Age (in years)  CAO Points (100 to 600)  \
# count          121.00                   121.00
# mean            22.20                   490.71
# std              5.11                    76.00
# min             18.00                   130.00
# 25%             20.00                   479.00
# 50%             21.00                   510.00
# 75%             22.00                   534.00
# max             58.00                   600.00
#
#        Daily travel to DCU (in km, 0 if on-campus)  \
# count                                       121.00
# mean                                         10.13
# std                                          15.31
# min                                           0.00
# 25%                                           2.00
# 50%                                           5.00
# 75%                                          12.00
# max                                         103.00
#
#        Average year 1 exam result (as %)  Seat row in class  \
# count                             121.00             121.00
# mean                               68.59               5.67
# std                                 8.47               2.73
# min                                42.00               1.00
# 25%                                65.00               4.00
# 50%                                68.00               5.00
# 75%                                72.00               8.00
# max                                99.00              12.00
#
#        Number of older siblings  Number of younger siblings  \
# count                    122.00                      122.00
# mean                       1.23                        0.91
# std                        1.10                        0.93
# min                        0.00                        0.00
# 25%                        1.00                        0.00
# 50%                        1.00                        1.00
# 75%                        2.00                        1.00
# max                        7.00                        4.00
#
#        Old Dublin postcode (0 if outside Dublin)  Height (in cm)  \
# count                                     122.00          122.00
# mean                                        5.28          176.27
# std                                         6.03           10.33
# min                                         0.00          150.00
# 25%                                         0.00          169.00
# 50%                                         2.50          177.00
# 75%                                         9.00          183.00
# max                                        24.00          198.00
#
#        Weight (in kg)  Last 4 digits of your mobile (0000 to 9999)  Shoe size
# count          122.00                                       122.00     122.00
# mean            72.29                                      4650.39       8.25
# std             12.58                                      2873.11       2.40
# min             51.00                                        59.00       3.00
# 25%             62.00                                      2228.75       6.00
# 50%             71.00                                      4641.00       9.00
# 75%             82.00                                      7164.50      10.00
# max            105.00                                      9898.00      13.00

# %%
demographics["Age (in years)"].unique()
# Out:
# array([21., 22., 20., 19., nan, 25., 23., 28., 36., 33., 24., 18., 32.,
#        26., 47., 58.])

# %%
demographics["Age (in years)"].value_counts()
# Out:
# 20.0    32
# 21.0    26
# 22.0    19
# 19.0    17
# 23.0     6
# 24.0     5
# 25.0     4
# 28.0     2
# 36.0     2
# 33.0     2
# 26.0     2
# 18.0     1
# 32.0     1
# 47.0     1
# 58.0     1
# Name: Age (in years), dtype: int64

# %%
demographics["Gender"].value_counts()
# Out:
# Male                 69
# Female               52
# Prefer not to say     1
# Name: Gender, dtype: int64

# %%
demographics["Seat row in class"].unique()
# Out:
# array([ 4.,  7.,  6., nan,  1.,  2.,  3., 10.,  5.,  8.,  9., 12., 11.])

# %%
demographics_is_na = demographics.iloc[:5, :].copy()
demographics_is_na
# Out:
#    Age (in years)  CAO Points (100 to 600)  \
# 0            21.0                      NaN
# 1            22.0                    505.0
# 2            20.0                    600.0
# 3            19.0                    543.0
# 4             NaN                    407.0
#
#    Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                         10.0
# 1                                          NaN
# 2                                         30.0
# 3                                         10.0
# 4                                          8.0
#
#    Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                               66.0                4.0    Male
# 1                               68.0                7.0  Female
# 2                                NaN                6.0  Female
# 3                               71.0                NaN    Male
# 4                               73.0                1.0    Male
#
#    Number of older siblings  Number of younger siblings  \
# 0                         0                           2
# 1                         0                           1
# 2                         1                           2
# 3                         0                           1
# 4                         2                           0
#
#    Old Dublin postcode (0 if outside Dublin)  Height (in cm)  Weight (in kg)  \
# 0                                          0           178.0            92.0
# 1                                          0           155.0            55.0
# 2                                          0           180.0            55.0
# 3                                         13           187.0            76.0
# 4                                         15           181.0            87.0
#
#   Eye colour Hair colour  Last 4 digits of your mobile (0000 to 9999)  \
# 0      Green       Brown                                         5262
# 1       Blue       Brown                                         7181
# 2       Blue       Brown                                         7677
# 3       Blue         Red                                          838
# 4       Blue       Brown                                         6290
#
#    Star sign  Shoe size
# 0  Capricorn        9.0
# 1        Leo        4.0
# 2        Leo        5.0
# 3     Taurus        9.0
# 4     Cancer        9.5

# %%
demographics_no_na = demographics.iloc[5:, :].copy()
demographics_no_na
# Out:
#      Age (in years)  CAO Points (100 to 600)  \
# 5              20.0                    484.0
# 6              21.0                    498.0
# 7              21.0                    498.0
# 8              19.0                    509.0
# 9              19.0                    566.0
# ..              ...                      ...
# 117            21.0                    565.0
# 118            20.0                    520.0
# 119            20.0                    510.0
# 120            23.0                    490.0
# 121            22.0                    500.0
#
#      Daily travel to DCU (in km, 0 if on-campus)  \
# 5                                            0.0
# 6                                            2.0
# 7                                           15.0
# 8                                           10.0
# 9                                            2.0
# ..                                           ...
# 117                                          7.0
# 118                                          7.0
# 119                                         60.0
# 120                                          7.0
# 121                                          4.0
#
#      Average year 1 exam result (as %)  Seat row in class  Gender  \
# 5                                 68.0                1.0    Male
# 6                                 82.0                2.0    Male
# 7                                 74.0                1.0    Male
# 8                                 64.0                3.0    Male
# 9                                 70.0               10.0  Female
# ..                                 ...                ...     ...
# 117                               71.0                3.0  Female
# 118                               62.0                8.0  Female
# 119                               65.0                5.0    Male
# 120                               70.0                4.0  Female
# 121                               65.0                4.0  Female
#
#      Number of older siblings  Number of younger siblings  \
# 5                           2                           1
# 6                           2                           1
# 7                           1                           1
# 8                           0                           0
# 9                           2                           0
# ..                        ...                         ...
# 117                         2                           1
# 118                         0                           2
# 119                         1                           1
# 120                         0                           3
# 121                         0                           3
#
#      Old Dublin postcode (0 if outside Dublin)  Height (in cm)  \
# 5                                            0           188.0
# 6                                            2           187.0
# 7                                           15           186.0
# 8                                            3           187.0
# 9                                            0           167.0
# ..                                         ...             ...
# 117                                         14           170.0
# 118                                          7           165.0
# 119                                          0           184.0
# 120                                          7           173.0
# 121                                          0           177.0
#
#      Weight (in kg) Eye colour Hair colour  \
# 5              73.0       Blue      Blonde
# 6             105.0      Brown       Brown
# 7              80.0       Blue         Red
# 8              68.0      Brown       Brown
# 9              60.0      Green       Brown
# ..              ...        ...         ...
# 117            59.0       Blue       Black
# 118            70.0       Blue       Black
# 119            85.0       Blue       Brown
# 120            73.0      Green      Blonde
# 121            73.0       Blue       Brown
#
#      Last 4 digits of your mobile (0000 to 9999) Star sign  Shoe size
# 5                                           6684    Taurus        9.5
# 6                                           7835    Gemini       11.0
# 7                                           6738    Taurus        9.5
# 8                                            608  Aquarius       10.0
# 9                                             87     Pices        5.0
# ..                                           ...       ...        ...
# 117                                         1699     Libra        6.0
# 118                                         5289    Taurus        5.0
# 119                                         5317     Libra       10.0
# 120                                         4602  Aquarius        7.0
# 121                                         6402       Leo        7.0
#
# [117 rows x 16 columns]

# %%
plt.scatter(demographics_no_na["Old Dublin postcode (0 if outside Dublin)"], demographics_no_na["Daily travel to DCU (in km, 0 if on-campus)"])
plt.title("Relation between Postcode and Daily Travel")
plt.xlabel("Postcode")
plt.ylabel("Daily Travel")
plt.show()

# %%
demographics_no_na_pd = demographics_no_na["Daily travel to DCU (in km, 0 if on-campus)"].unique()
np.set_printoptions(suppress=True, precision =2)
demographics_no_na_pd
# Out:
# array([  0.  ,   2.  ,  15.  ,  10.  ,   5.  ,  20.  ,   1.  ,   3.  ,
#          3.5 ,  78.  ,   4.  ,   0.5 ,  46.  ,   8.  ,   6.  ,   4.5 ,
#          6.7 ,   7.  ,   5.5 ,  31.  ,  24.  ,   4.4 ,   0.05,  27.  ,
#         17.  ,  12.  ,   4.8 ,   4.2 ,  11.  ,  13.  ,   4.7 ,   9.  ,
#         35.  ,  42.  ,  21.  ,   1.7 ,  59.  ,  25.  , 103.  ,  18.  ,
#         60.  ])

# %%
demographics_no_na[demographics_no_na["Old Dublin postcode (0 if outside Dublin)"] == 0]["Old Dublin postcode (0 if outside Dublin)"].count()
# Out:
# 46

# %%
demographics_no_na_post_dist = demographics_no_na[["Daily travel to DCU (in km, 0 if on-campus)", "Old Dublin postcode (0 if outside Dublin)"]]
demographics_no_na_post_dist.groupby("Old Dublin postcode (0 if outside Dublin)").mean()
# Out:
#                                            Daily travel to DCU (in km, 0 if on-campus)
# Old Dublin postcode (0 if outside Dublin)
# 0                                                                            11.603261
# 1                                                                             4.910000
# 2                                                                             1.000000
# 3                                                                             5.800000
# 4                                                                            59.000000
# 5                                                                            22.333333
# 7                                                                             8.027273
# 9                                                                             2.727273
# 11                                                                            2.744444
# 12                                                                           15.925000
# 13                                                                           10.666667
# 14                                                                            7.000000
# 15                                                                           15.666667
# 18                                                                           20.000000
# 19                                                                           14.000000
# 22                                                                           20.000000
# 24                                                                           20.000000

# %%
demographics_no_na_post_dist.groupby("Old Dublin postcode (0 if outside Dublin)").max()
# Out:
#                                            Daily travel to DCU (in km, 0 if on-campus)
# Old Dublin postcode (0 if outside Dublin)
# 0                                                                                103.0
# 1                                                                                 10.0
# 2                                                                                  2.0
# 3                                                                                 10.0
# 4                                                                                 59.0
# 5                                                                                 35.0
# 7                                                                                 20.0
# 9                                                                                  5.0
# 11                                                                                 5.0
# 12                                                                                46.0
# 13                                                                                12.0
# 14                                                                                 7.0
# 15                                                                                17.0
# 18                                                                                20.0
# 19                                                                                27.0
# 22                                                                                20.0
# 24                                                                                20.0

# %%
demographics_no_na_post_dist.groupby("Old Dublin postcode (0 if outside Dublin)").std()
# Out:
#                                            Daily travel to DCU (in km, 0 if on-campus)
# Old Dublin postcode (0 if outside Dublin)
# 0                                                                            21.051868
# 1                                                                             2.589916
# 2                                                                             1.414214
# 3                                                                             5.310367
# 4                                                                                  NaN
# 5                                                                            13.576941
# 7                                                                             6.028945
# 9                                                                             1.902152
# 11                                                                            1.418724
# 12                                                                           20.062133
# 13                                                                            1.527525
# 14                                                                                 NaN
# 15                                                                            1.032796
# 18                                                                                 NaN
# 19                                                                           18.384776
# 22                                                                                 NaN
# 24                                                                                 NaN

# %%
demographics_is_na.iloc[1,2] = 11.60
demographics_is_na
# Out:
#    Age (in years)  CAO Points (100 to 600)  \
# 0            21.0                      NaN
# 1            22.0                    505.0
# 2            20.0                    600.0
# 3            19.0                    543.0
# 4             NaN                    407.0
#
#    Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                         10.0
# 1                                         11.6
# 2                                         30.0
# 3                                         10.0
# 4                                          8.0
#
#    Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                               66.0                4.0    Male
# 1                               68.0                7.0  Female
# 2                                NaN                6.0  Female
# 3                               71.0                NaN    Male
# 4                               73.0                1.0    Male
#
#    Number of older siblings  Number of younger siblings  \
# 0                         0                           2
# 1                         0                           1
# 2                         1                           2
# 3                         0                           1
# 4                         2                           0
#
#    Old Dublin postcode (0 if outside Dublin)  Height (in cm)  Weight (in kg)  \
# 0                                          0           178.0            92.0
# 1                                          0           155.0            55.0
# 2                                          0           180.0            55.0
# 3                                         13           187.0            76.0
# 4                                         15           181.0            87.0
#
#   Eye colour Hair colour  Last 4 digits of your mobile (0000 to 9999)  \
# 0      Green       Brown                                         5262
# 1       Blue       Brown                                         7181
# 2       Blue       Brown                                         7677
# 3       Blue         Red                                          838
# 4       Blue       Brown                                         6290
#
#    Star sign  Shoe size
# 0  Capricorn        9.0
# 1        Leo        4.0
# 2        Leo        5.0
# 3     Taurus        9.0
# 4     Cancer        9.5

# %%
# import libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demographics_no_na[['Age (in years)','Average year 1 exam result (as %)']]
yDf = demographics_no_na['CAO Points (100 to 600)']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin.score(X_test, y_test))
print(reg_lin.coef_)
print(reg_lin.predict([[21,66]]))
# Out:
# 0.07764305496508461
# [-1.15  1.16]
# [491.16]
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
demographics_is_na.iloc[0,1] = 491
demographics_is_na
# Out:
#    Age (in years)  CAO Points (100 to 600)  \
# 0            21.0                    491.0
# 1            22.0                    505.0
# 2            20.0                    600.0
# 3            19.0                    543.0
# 4             NaN                    407.0
#
#    Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                         10.0
# 1                                         11.6
# 2                                         30.0
# 3                                         10.0
# 4                                          8.0
#
#    Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                               66.0                4.0    Male
# 1                               68.0                7.0  Female
# 2                                NaN                6.0  Female
# 3                               71.0                NaN    Male
# 4                               73.0                1.0    Male
#
#    Number of older siblings  Number of younger siblings  \
# 0                         0                           2
# 1                         0                           1
# 2                         1                           2
# 3                         0                           1
# 4                         2                           0
#
#    Old Dublin postcode (0 if outside Dublin)  Height (in cm)  Weight (in kg)  \
# 0                                          0           178.0            92.0
# 1                                          0           155.0            55.0
# 2                                          0           180.0            55.0
# 3                                         13           187.0            76.0
# 4                                         15           181.0            87.0
#
#   Eye colour Hair colour  Last 4 digits of your mobile (0000 to 9999)  \
# 0      Green       Brown                                         5262
# 1       Blue       Brown                                         7181
# 2       Blue       Brown                                         7677
# 3       Blue         Red                                          838
# 4       Blue       Brown                                         6290
#
#    Star sign  Shoe size
# 0  Capricorn        9.0
# 1        Leo        4.0
# 2        Leo        5.0
# 3     Taurus        9.0
# 4     Cancer        9.5

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demographics_no_na[['Age (in years)', 'CAO Points (100 to 600)']]
yDf = demographics_no_na['Average year 1 exam result (as %)']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin.score(X_test, y_test))
print(reg_lin.coef_)
print(reg_lin.predict([[20,600]]))
# Out:
# 0.10728121697137338
# [0.12 0.02]
# [70.54]
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
demographics_is_na.iloc[2,3] = 70.5
demographics_is_na
# Out:
#    Age (in years)  CAO Points (100 to 600)  \
# 0            21.0                    491.0
# 1            22.0                    505.0
# 2            20.0                    600.0
# 3            19.0                    543.0
# 4             NaN                    407.0
#
#    Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                         10.0
# 1                                         11.6
# 2                                         30.0
# 3                                         10.0
# 4                                          8.0
#
#    Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                               66.0                4.0    Male
# 1                               68.0                7.0  Female
# 2                               70.5                6.0  Female
# 3                               71.0                NaN    Male
# 4                               73.0                1.0    Male
#
#    Number of older siblings  Number of younger siblings  \
# 0                         0                           2
# 1                         0                           1
# 2                         1                           2
# 3                         0                           1
# 4                         2                           0
#
#    Old Dublin postcode (0 if outside Dublin)  Height (in cm)  Weight (in kg)  \
# 0                                          0           178.0            92.0
# 1                                          0           155.0            55.0
# 2                                          0           180.0            55.0
# 3                                         13           187.0            76.0
# 4                                         15           181.0            87.0
#
#   Eye colour Hair colour  Last 4 digits of your mobile (0000 to 9999)  \
# 0      Green       Brown                                         5262
# 1       Blue       Brown                                         7181
# 2       Blue       Brown                                         7677
# 3       Blue         Red                                          838
# 4       Blue       Brown                                         6290
#
#    Star sign  Shoe size
# 0  Capricorn        9.0
# 1        Leo        4.0
# 2        Leo        5.0
# 3     Taurus        9.0
# 4     Cancer        9.5

# %%
# Split the data columnwise into the independent variables (x) and the dependent variable (y)
xDf = demographics_no_na[['Age (in years)', 'CAO Points (100 to 600)', "Average year 1 exam result (as %)"]]
yDf = demographics_no_na['Seat row in class']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin.score(X_test, y_test))
print(reg_lin.coef_)
print(reg_lin.predict([[19,543,71]]))
# Out:
# -0.07013573261755024
# [ 0.19  0.   -0.04]
# [5.2]
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#no meaningful correlation which was not expected in any other way
np.random.randint(1,12)
# Out:
# 7

# %%
demographics_is_na.iloc[3,4] = 7
demographics_is_na
# Out:
#    Age (in years)  CAO Points (100 to 600)  \
# 0            21.0                    491.0
# 1            22.0                    505.0
# 2            20.0                    600.0
# 3            19.0                    543.0
# 4            21.0                    407.0
#
#    Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                         10.0
# 1                                         11.6
# 2                                         30.0
# 3                                         10.0
# 4                                          8.0
#
#    Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                               66.0                4.0    Male
# 1                               68.0                7.0  Female
# 2                               70.5                6.0  Female
# 3                               71.0                7.0    Male
# 4                               73.0                1.0    Male
#
#    Number of older siblings  Number of younger siblings  \
# 0                         0                           2
# 1                         0                           1
# 2                         1                           2
# 3                         0                           1
# 4                         2                           0
#
#    Old Dublin postcode (0 if outside Dublin)  Height (in cm)  Weight (in kg)  \
# 0                                          0           178.0            92.0
# 1                                          0           155.0            55.0
# 2                                          0           180.0            55.0
# 3                                         13           187.0            76.0
# 4                                         15           181.0            87.0
#
#   Eye colour Hair colour  Last 4 digits of your mobile (0000 to 9999)  \
# 0      Green       Brown                                         5262
# 1       Blue       Brown                                         7181
# 2       Blue       Brown                                         7677
# 3       Blue         Red                                          838
# 4       Blue       Brown                                         6290
#
#    Star sign  Shoe size
# 0  Capricorn        9.0
# 1        Leo        4.0
# 2        Leo        5.0
# 3     Taurus        9.0
# 4     Cancer        9.5

# %%
#because we cannot predict the age here we use the median to fill it in
demographics_is_na.iloc[4,0] = 21
demographics_is_na
# Out:
#    Age (in years)  CAO Points (100 to 600)  \
# 0            21.0                    491.0
# 1            22.0                    505.0
# 2            20.0                    600.0
# 3            19.0                    543.0
# 4            21.0                    407.0
#
#    Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                         10.0
# 1                                         11.6
# 2                                         30.0
# 3                                         10.0
# 4                                          8.0
#
#    Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                               66.0                4.0    Male
# 1                               68.0                7.0  Female
# 2                               70.5                6.0  Female
# 3                               71.0                7.0    Male
# 4                               73.0                1.0    Male
#
#    Number of older siblings  Number of younger siblings  \
# 0                         0                           2
# 1                         0                           1
# 2                         1                           2
# 3                         0                           1
# 4                         2                           0
#
#    Old Dublin postcode (0 if outside Dublin)  Height (in cm)  Weight (in kg)  \
# 0                                          0           178.0            92.0
# 1                                          0           155.0            55.0
# 2                                          0           180.0            55.0
# 3                                         13           187.0            76.0
# 4                                         15           181.0            87.0
#
#   Eye colour Hair colour  Last 4 digits of your mobile (0000 to 9999)  \
# 0      Green       Brown                                         5262
# 1       Blue       Brown                                         7181
# 2       Blue       Brown                                         7677
# 3       Blue         Red                                          838
# 4       Blue       Brown                                         6290
#
#    Star sign  Shoe size
# 0  Capricorn        9.0
# 1        Leo        4.0
# 2        Leo        5.0
# 3     Taurus        9.0
# 4     Cancer        9.5

# %%
normalised_demographics = pd.concat([demographics_is_na, demographics_no_na], axis = 0)
normalised_demographics
# Out:
#      Age (in years)  CAO Points (100 to 600)  \
# 0              21.0                    491.0
# 1              22.0                    505.0
# 2              20.0                    600.0
# 3              19.0                    543.0
# 4              21.0                    407.0
# ..              ...                      ...
# 117            21.0                    565.0
# 118            20.0                    520.0
# 119            20.0                    510.0
# 120            23.0                    490.0
# 121            22.0                    500.0
#
#      Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                           10.0
# 1                                           11.6
# 2                                           30.0
# 3                                           10.0
# 4                                            8.0
# ..                                           ...
# 117                                          7.0
# 118                                          7.0
# 119                                         60.0
# 120                                          7.0
# 121                                          4.0
#
#      Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                                 66.0                4.0    Male
# 1                                 68.0                7.0  Female
# 2                                 70.5                6.0  Female
# 3                                 71.0                7.0    Male
# 4                                 73.0                1.0    Male
# ..                                 ...                ...     ...
# 117                               71.0                3.0  Female
# 118                               62.0                8.0  Female
# 119                               65.0                5.0    Male
# 120                               70.0                4.0  Female
# 121                               65.0                4.0  Female
#
#      Number of older siblings  Number of younger siblings  \
# 0                           0                           2
# 1                           0                           1
# 2                           1                           2
# 3                           0                           1
# 4                           2                           0
# ..                        ...                         ...
# 117                         2                           1
# 118                         0                           2
# 119                         1                           1
# 120                         0                           3
# 121                         0                           3
#
#      Old Dublin postcode (0 if outside Dublin)  Height (in cm)  \
# 0                                            0           178.0
# 1                                            0           155.0
# 2                                            0           180.0
# 3                                           13           187.0
# 4                                           15           181.0
# ..                                         ...             ...
# 117                                         14           170.0
# 118                                          7           165.0
# 119                                          0           184.0
# 120                                          7           173.0
# 121                                          0           177.0
#
#      Weight (in kg) Eye colour Hair colour  \
# 0              92.0      Green       Brown
# 1              55.0       Blue       Brown
# 2              55.0       Blue       Brown
# 3              76.0       Blue         Red
# 4              87.0       Blue       Brown
# ..              ...        ...         ...
# 117            59.0       Blue       Black
# 118            70.0       Blue       Black
# 119            85.0       Blue       Brown
# 120            73.0      Green      Blonde
# 121            73.0       Blue       Brown
#
#      Last 4 digits of your mobile (0000 to 9999)  Star sign  Shoe size
# 0                                           5262  Capricorn        9.0
# 1                                           7181        Leo        4.0
# 2                                           7677        Leo        5.0
# 3                                            838     Taurus        9.0
# 4                                           6290     Cancer        9.5
# ..                                           ...        ...        ...
# 117                                         1699      Libra        6.0
# 118                                         5289     Taurus        5.0
# 119                                         5317      Libra       10.0
# 120                                         4602   Aquarius        7.0
# 121                                         6402        Leo        7.0
#
# [122 rows x 16 columns]

# %%
inpPath2 = "C:/CarolineZiegler/Studium_DCU/8. Semester/Data Analytics for Marketing Applications/Pair Assignments/"
personalities = pd.read_csv(inpPath2 + "personalities.csv", delimiter =  ",", header = 0)
personalities
# Out:
#      Last 4 digits of your mobile (same as on previous form)  \
# 0                                                 7703
# 1                                                 5406
# 2                                                 7181
# 3                                                  971
# 4                                                 7263
# ..                                                 ...
# 98                                                4602
# 99                                                3839
# 100                                               5085
# 101                                               6402
# 102                                               1573
#
#      Your rating for EXTRAVERSION (vs. introversion)  \
# 0                                                 71
# 1                                                 60
# 2                                                 32
# 3                                                 46
# 4                                                 29
# ..                                               ...
# 98                                                29
# 99                                                70
# 100                                               22
# 101                                               78
# 102                                               81
#
#      Your rating for INTUITION (vs. observation)  \
# 0                                             66
# 1                                             68
# 2                                             62
# 3                                             48
# 4                                             79
# ..                                           ...
# 98                                            23
# 99                                            50
# 100                                           93
# 101                                           68
# 102                                           49
#
#      Your rating for THINKING (vs. feeling)  \
# 0                                        65
# 1                                        30
# 2                                        23
# 3                                        34
# 4                                        23
# ..                                      ...
# 98                                       32
# 99                                       25
# 100                                      44
# 101                                      53
# 102                                      55
#
#      Your rating for JUDGING (vs. prospecting)  \
# 0                                           31
# 1                                           35
# 2                                           35
# 3                                           64
# 4                                           83
# ..                                         ...
# 98                                          60
# 99                                          24
# 100                                         83
# 101                                         71
# 102                                         61
#
#      Your rating for ASSERTIVE (vs. turbulent)
# 0                                           81
# 1                                           33
# 2                                           31
# 3                                           42
# 4                                           39
# ..                                         ...
# 98                                          32
# 99                                          46
# 100                                          8
# 101                                         63
# 102                                         64
#
# [103 rows x 6 columns]

# %%
personalities.rename(columns = {"Last 4 digits of your mobile (same as on previous form)": "Last 4 digits of your mobile (0000 to 9999)", 
                        "Your rating for EXTRAVERSION (vs. introversion)":"Extraversion", 
                        "Your rating for INTUITION (vs. observation)": "Intuition", 
                        "Your rating for THINKING (vs. feeling)":"Thinking", 
                        "Your rating for JUDGING (vs. prospecting)":"Judging", 
                        "Your rating for ASSERTIVE (vs. turbulent)":"Assertive",
                        }, inplace = True)
personalities
# Out:
#      Last 4 digits of your mobile (0000 to 9999)  Extraversion  Intuition  \
# 0                                           7703            71         66
# 1                                           5406            60         68
# 2                                           7181            32         62
# 3                                            971            46         48
# 4                                           7263            29         79
# ..                                           ...           ...        ...
# 98                                          4602            29         23
# 99                                          3839            70         50
# 100                                         5085            22         93
# 101                                         6402            78         68
# 102                                         1573            81         49
#
#      Thinking  Judging  Assertive
# 0          65       31         81
# 1          30       35         33
# 2          23       35         31
# 3          34       64         42
# 4          23       83         39
# ..        ...      ...        ...
# 98         32       60         32
# 99         25       24         46
# 100        44       83          8
# 101        53       71         63
# 102        55       61         64
#
# [103 rows x 6 columns]

# %%
personalities[personalities["Last 4 digits of your mobile (0000 to 9999)"] == 4397]
# Out:
#     Last 4 digits of your mobile (0000 to 9999)  Extraversion  Intuition  \
# 22                                         4397            74         48
# 53                                         4397            65         70
#
#     Thinking  Judging  Assertive
# 22        43       29         63
# 53        70       65         60

# %%
personalities.drop(53, axis =0, inplace = True)
personalities
# Out:
#      Last 4 digits of your mobile (0000 to 9999)  Extraversion  Intuition  \
# 0                                           7703            71         66
# 1                                           5406            60         68
# 2                                           7181            32         62
# 3                                            971            46         48
# 4                                           7263            29         79
# ..                                           ...           ...        ...
# 98                                          4602            29         23
# 99                                          3839            70         50
# 100                                         5085            22         93
# 101                                         6402            78         68
# 102                                         1573            81         49
#
#      Thinking  Judging  Assertive
# 0          65       31         81
# 1          30       35         33
# 2          23       35         31
# 3          34       64         42
# 4          23       83         39
# ..        ...      ...        ...
# 98         32       60         32
# 99         25       24         46
# 100        44       83          8
# 101        53       71         63
# 102        55       61         64
#
# [102 rows x 6 columns]

# %%
personalities[personalities["Last 4 digits of your mobile (0000 to 9999)"] == 4397]
# Out:
#     Last 4 digits of your mobile (0000 to 9999)  Extraversion  Intuition  \
# 22                                         4397            74         48
#
#     Thinking  Judging  Assertive
# 22        43       29         63

# %%
demo_perso = normalised_demographics.merge(personalities, on = "Last 4 digits of your mobile (0000 to 9999)", 
                                           how = "inner")
demo_perso
# Out:
#     Age (in years)  CAO Points (100 to 600)  \
# 0             22.0                    505.0
# 1             19.0                    543.0
# 2             21.0                    557.0
# 3             22.0                    397.0
# 4             25.0                    532.0
# ..             ...                      ...
# 62            21.0                    565.0
# 63            20.0                    520.0
# 64            20.0                    510.0
# 65            23.0                    490.0
# 66            22.0                    500.0
#
#     Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                          11.6
# 1                                          10.0
# 2                                          15.0
# 3                                           5.0
# 4                                          20.0
# ..                                          ...
# 62                                          7.0
# 63                                          7.0
# 64                                         60.0
# 65                                          7.0
# 66                                          4.0
#
#     Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                                68.0                7.0  Female
# 1                                71.0                2.0    Male
# 2                                50.5               10.0    Male
# 3                                65.0                5.0  Female
# 4                                72.0                8.0    Male
# ..                                ...                ...     ...
# 62                               71.0                3.0  Female
# 63                               62.0                8.0  Female
# 64                               65.0                5.0    Male
# 65                               70.0                4.0  Female
# 66                               65.0                4.0  Female
#
#     Number of older siblings  Number of younger siblings  \
# 0                          0                           1
# 1                          0                           1
# 2                          2                           0
# 3                          2                           0
# 4                          1                           1
# ..                       ...                         ...
# 62                         2                           1
# 63                         0                           2
# 64                         1                           1
# 65                         0                           3
# 66                         0                           3
#
#     Old Dublin postcode (0 if outside Dublin)  Height (in cm)  ...  \
# 0                                           0           155.0  ...
# 1                                          13           187.0  ...
# 2                                          15           178.0  ...
# 3                                           0           153.0  ...
# 4                                          22           192.0  ...
# ..                                        ...             ...  ...
# 62                                         14           170.0  ...
# 63                                          7           165.0  ...
# 64                                          0           184.0  ...
# 65                                          7           173.0  ...
# 66                                          0           177.0  ...
#
#     Eye colour Hair colour Last 4 digits of your mobile (0000 to 9999)  \
# 0         Blue       Brown                                        7181
# 1         Blue         Red                                         838
# 2        Green       Brown                                        4397
# 3        Brown       Brown                                        8626
# 4        Green       Brown                                        4768
# ..         ...         ...                                         ...
# 62        Blue       Black                                        1699
# 63        Blue       Black                                        5289
# 64        Blue       Brown                                        5317
# 65       Green      Blonde                                        4602
# 66        Blue       Brown                                        6402
#
#       Star sign Shoe size  Extraversion  Intuition  Thinking  Judging  \
# 0           Leo       4.0            32         62        23       35
# 1        Taurus       9.0            48         41        57       49
# 2         Aries       7.0            74         48        43       29
# 3   Sagittarius       5.0            25         55        43       61
# 4      Aquarius      12.0            56         68        27       47
# ..          ...       ...           ...        ...       ...      ...
# 62        Libra       6.0            64         69        63       58
# 63       Taurus       5.0            61         55        66       49
# 64        Libra      10.0            25         24        49       44
# 65     Aquarius       7.0            29         23        32       60
# 66          Leo       7.0            78         68        53       71
#
#     Assertive
# 0          31
# 1          36
# 2          63
# 3          44
# 4          49
# ..        ...
# 62         60
# 63         67
# 64         10
# 65         32
# 66         63
#
# [67 rows x 21 columns]

# %%
personalities["Last 4 digits of your mobile (0000 to 9999)"].unique()
# Out:
# array([7703, 5406, 7181,  971, 7263, 5411, 1122, 7335, 7767, 2666, 3308,
#        8798, 4091, 8995, 1699, 4920, 9552, 1278, 3660, 2424,  316, 5317,
#        4397, 5870,  838, 4118, 7084, 3320, 3305, 1128, 8510, 7305,  949,
#        1446, 8826,  111, 6413, 4768,   97, 8007, 8626, 1816, 5692, 8934,
#        2070, 9000, 1427,  906, 9904, 1462, 2740, 4250, 6909, 5552, 6138,
#        9898, 6944, 8421, 1049, 2288,  730,  987, 3173, 2228, 8619, 2986,
#        4230, 6225, 2785,  417, 7865, 7052,  999, 6984, 5349, 4253, 7721,
#        7115, 7795, 3513, 4791,  460,  904, 2004, 2559, 9487, 6521, 8947,
#        3484, 5289, 9893, 8188, 5311, 6263, 2803, 4602, 3839, 5085, 6402,
#        1573], dtype=int64)

# %%
personalities["Last 4 digits of your mobile (0000 to 9999)"].value_counts()
# Out:
# 1699    2
# 1462    2
# 7703    1
# 6984    1
# 999     1
#        ..
# 7305    1
# 8510    1
# 1128    1
# 3305    1
# 1573    1
# Name: Last 4 digits of your mobile (0000 to 9999), Length: 100, dtype: int64

# %%
normalised_demographics["Last 4 digits of your mobile (0000 to 9999)"].unique()
# Out:
# array([5262, 7181, 7677,  838, 6290, 6684, 7835, 6738,  608,   87, 4397,
#        8626, 4768, 3173, 4250, 8510, 9610,  904, 2803, 8995, 2666, 2288,
#        7654, 6413, 8798, 1278, 7305, 2231, 7501, 2785, 8091, 8973, 3220,
#        1816, 7896, 1128,  111, 2356, 1546,  844, 5141, 2955,  602, 4839,
#        2408, 6984,  460, 1049, 2576, 3988, 1352, 6552, 4091,  937, 1462,
#        7703, 4253, 5567, 9876,  817, 6798, 2561, 4653, 1238,  730, 8107,
#        1446, 7489, 5406, 7386, 2228,  971, 8118, 4629, 4791, 7987, 3513,
#         999,  130, 3559, 8903, 6666, 8532, 5692, 7115, 2424, 1291, 9145,
#        4118, 3349, 3675, 8188, 5749, 6969, 6263, 1145, 8007, 3308, 1024,
#        2523, 5870, 7084, 3320,  949, 6138, 7721, 6944, 9898, 8421,  987,
#          59, 2986, 4230, 7865, 4920, 9552, 6521, 1699, 5289, 5317, 4602,
#        6402], dtype=int64)

# %%
common_lst = []
for el in normalised_demographics['Last 4 digits of your mobile (0000 to 9999)'].unique():
    if el in personalities['Last 4 digits of your mobile (0000 to 9999)'].unique():
        common_lst.append(el)
print(len(common_lst))
# Out:
# 65

# %%
print(common_lst)
# Out:
# [7181, 838, 4397, 8626, 4768, 3173, 4250, 8510, 904, 2803, 8995, 2666, 2288, 6413, 8798, 1278, 7305, 2785, 1816, 1128, 111, 6984, 460, 1049, 4091, 1462, 7703, 4253, 730, 1446, 5406, 2228, 971, 4791, 3513, 999, 5692, 7115, 2424, 4118, 8188, 6263, 8007, 3308, 5870, 7084, 3320, 949, 6138, 7721, 6944, 9898, 8421, 987, 2986, 4230, 7865, 4920, 9552, 6521, 1699, 5289, 5317, 4602, 6402]

# %%
personalities[personalities["Last 4 digits of your mobile (0000 to 9999)"] == 1699]
# Out:
#     Last 4 digits of your mobile (0000 to 9999)  Extraversion  Intuition  \
# 14                                         1699            64         69
# 89                                         1699            64         69
#
#     Thinking  Judging  Assertive
# 14        63       58         60
# 89        63       58         60

# %%
personalities[personalities["Last 4 digits of your mobile (0000 to 9999)"] == 1462]
# Out:
#     Last 4 digits of your mobile (0000 to 9999)  Extraversion  Intuition  \
# 49                                         1462            68         68
# 97                                         1462            78         72
#
#     Thinking  Judging  Assertive
# 49        46       71         49
# 97        46       60         37

# %%
personalities.drop(89, axis =0, inplace = True)
personalities
# Out:
#      Last 4 digits of your mobile (0000 to 9999)  Extraversion  Intuition  \
# 0                                           7703            71         66
# 1                                           5406            60         68
# 2                                           7181            32         62
# 3                                            971            46         48
# 4                                           7263            29         79
# ..                                           ...           ...        ...
# 98                                          4602            29         23
# 99                                          3839            70         50
# 100                                         5085            22         93
# 101                                         6402            78         68
# 102                                         1573            81         49
#
#      Thinking  Judging  Assertive
# 0          65       31         81
# 1          30       35         33
# 2          23       35         31
# 3          34       64         42
# 4          23       83         39
# ..        ...      ...        ...
# 98         32       60         32
# 99         25       24         46
# 100        44       83          8
# 101        53       71         63
# 102        55       61         64
#
# [101 rows x 6 columns]

# %%
personalities.drop(97, axis =0, inplace = True)
personalities
# Out:
#      Last 4 digits of your mobile (0000 to 9999)  Extraversion  Intuition  \
# 0                                           7703            71         66
# 1                                           5406            60         68
# 2                                           7181            32         62
# 3                                            971            46         48
# 4                                           7263            29         79
# ..                                           ...           ...        ...
# 98                                          4602            29         23
# 99                                          3839            70         50
# 100                                         5085            22         93
# 101                                         6402            78         68
# 102                                         1573            81         49
#
#      Thinking  Judging  Assertive
# 0          65       31         81
# 1          30       35         33
# 2          23       35         31
# 3          34       64         42
# 4          23       83         39
# ..        ...      ...        ...
# 98         32       60         32
# 99         25       24         46
# 100        44       83          8
# 101        53       71         63
# 102        55       61         64
#
# [100 rows x 6 columns]

# %%
demo_perso = normalised_demographics.merge(personalities, on = "Last 4 digits of your mobile (0000 to 9999)", how = "inner")
demo_perso
# Out:
#     Age (in years)  CAO Points (100 to 600)  \
# 0             22.0                    505.0
# 1             19.0                    543.0
# 2             21.0                    557.0
# 3             22.0                    397.0
# 4             25.0                    532.0
# ..             ...                      ...
# 60            21.0                    565.0
# 61            20.0                    520.0
# 62            20.0                    510.0
# 63            23.0                    490.0
# 64            22.0                    500.0
#
#     Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                          11.6
# 1                                          10.0
# 2                                          15.0
# 3                                           5.0
# 4                                          20.0
# ..                                          ...
# 60                                          7.0
# 61                                          7.0
# 62                                         60.0
# 63                                          7.0
# 64                                          4.0
#
#     Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                                68.0                7.0  Female
# 1                                71.0                2.0    Male
# 2                                50.5               10.0    Male
# 3                                65.0                5.0  Female
# 4                                72.0                8.0    Male
# ..                                ...                ...     ...
# 60                               71.0                3.0  Female
# 61                               62.0                8.0  Female
# 62                               65.0                5.0    Male
# 63                               70.0                4.0  Female
# 64                               65.0                4.0  Female
#
#     Number of older siblings  Number of younger siblings  \
# 0                          0                           1
# 1                          0                           1
# 2                          2                           0
# 3                          2                           0
# 4                          1                           1
# ..                       ...                         ...
# 60                         2                           1
# 61                         0                           2
# 62                         1                           1
# 63                         0                           3
# 64                         0                           3
#
#     Old Dublin postcode (0 if outside Dublin)  Height (in cm)  ...  \
# 0                                           0           155.0  ...
# 1                                          13           187.0  ...
# 2                                          15           178.0  ...
# 3                                           0           153.0  ...
# 4                                          22           192.0  ...
# ..                                        ...             ...  ...
# 60                                         14           170.0  ...
# 61                                          7           165.0  ...
# 62                                          0           184.0  ...
# 63                                          7           173.0  ...
# 64                                          0           177.0  ...
#
#     Eye colour Hair colour Last 4 digits of your mobile (0000 to 9999)  \
# 0         Blue       Brown                                        7181
# 1         Blue         Red                                         838
# 2        Green       Brown                                        4397
# 3        Brown       Brown                                        8626
# 4        Green       Brown                                        4768
# ..         ...         ...                                         ...
# 60        Blue       Black                                        1699
# 61        Blue       Black                                        5289
# 62        Blue       Brown                                        5317
# 63       Green      Blonde                                        4602
# 64        Blue       Brown                                        6402
#
#       Star sign Shoe size  Extraversion  Intuition  Thinking  Judging  \
# 0           Leo       4.0            32         62        23       35
# 1        Taurus       9.0            48         41        57       49
# 2         Aries       7.0            74         48        43       29
# 3   Sagittarius       5.0            25         55        43       61
# 4      Aquarius      12.0            56         68        27       47
# ..          ...       ...           ...        ...       ...      ...
# 60        Libra       6.0            64         69        63       58
# 61       Taurus       5.0            61         55        66       49
# 62        Libra      10.0            25         24        49       44
# 63     Aquarius       7.0            29         23        32       60
# 64          Leo       7.0            78         68        53       71
#
#     Assertive
# 0          31
# 1          36
# 2          63
# 3          44
# 4          49
# ..        ...
# 60         60
# 61         67
# 62         10
# 63         32
# 64         63
#
# [65 rows x 21 columns]

# %%
demo_perso_outer = normalised_demographics.merge(personalities, on = "Last 4 digits of your mobile (0000 to 9999)", how = "outer")
demo_perso_outer
# Out:
#      Age (in years)  CAO Points (100 to 600)  \
# 0              21.0                    491.0
# 1              22.0                    505.0
# 2              20.0                    600.0
# 3              19.0                    543.0
# 4              21.0                    407.0
# ..              ...                      ...
# 152             NaN                      NaN
# 153             NaN                      NaN
# 154             NaN                      NaN
# 155             NaN                      NaN
# 156             NaN                      NaN
#
#      Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                           10.0
# 1                                           11.6
# 2                                           30.0
# 3                                           10.0
# 4                                            8.0
# ..                                           ...
# 152                                          NaN
# 153                                          NaN
# 154                                          NaN
# 155                                          NaN
# 156                                          NaN
#
#      Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                                 66.0                4.0    Male
# 1                                 68.0                7.0  Female
# 2                                 70.5                6.0  Female
# 3                                 71.0                2.0    Male
# 4                                 73.0                1.0    Male
# ..                                 ...                ...     ...
# 152                                NaN                NaN     NaN
# 153                                NaN                NaN     NaN
# 154                                NaN                NaN     NaN
# 155                                NaN                NaN     NaN
# 156                                NaN                NaN     NaN
#
#      Number of older siblings  Number of younger siblings  \
# 0                         0.0                         2.0
# 1                         0.0                         1.0
# 2                         1.0                         2.0
# 3                         0.0                         1.0
# 4                         2.0                         0.0
# ..                        ...                         ...
# 152                       NaN                         NaN
# 153                       NaN                         NaN
# 154                       NaN                         NaN
# 155                       NaN                         NaN
# 156                       NaN                         NaN
#
#      Old Dublin postcode (0 if outside Dublin)  Height (in cm)  ...  \
# 0                                          0.0           178.0  ...
# 1                                          0.0           155.0  ...
# 2                                          0.0           180.0  ...
# 3                                         13.0           187.0  ...
# 4                                         15.0           181.0  ...
# ..                                         ...             ...  ...
# 152                                        NaN             NaN  ...
# 153                                        NaN             NaN  ...
# 154                                        NaN             NaN  ...
# 155                                        NaN             NaN  ...
# 156                                        NaN             NaN  ...
#
#      Eye colour Hair colour Last 4 digits of your mobile (0000 to 9999)  \
# 0         Green       Brown                                        5262
# 1          Blue       Brown                                        7181
# 2          Blue       Brown                                        7677
# 3          Blue         Red                                         838
# 4          Blue       Brown                                        6290
# ..          ...         ...                                         ...
# 152         NaN         NaN                                        9893
# 153         NaN         NaN                                        5311
# 154         NaN         NaN                                        3839
# 155         NaN         NaN                                        5085
# 156         NaN         NaN                                        1573
#
#      Star sign Shoe size  Extraversion  Intuition  Thinking  Judging  \
# 0    Capricorn       9.0           NaN        NaN       NaN      NaN
# 1          Leo       4.0          32.0       62.0      23.0     35.0
# 2          Leo       5.0           NaN        NaN       NaN      NaN
# 3       Taurus       9.0          48.0       41.0      57.0     49.0
# 4       Cancer       9.5           NaN        NaN       NaN      NaN
# ..         ...       ...           ...        ...       ...      ...
# 152        NaN       NaN          71.0       52.0      44.0     58.0
# 153        NaN       NaN          36.0       27.0      59.0     79.0
# 154        NaN       NaN          70.0       50.0      25.0     24.0
# 155        NaN       NaN          22.0       93.0      44.0     83.0
# 156        NaN       NaN          81.0       49.0      55.0     61.0
#
#      Assertive
# 0          NaN
# 1         31.0
# 2          NaN
# 3         36.0
# 4          NaN
# ..         ...
# 152       81.0
# 153       43.0
# 154       46.0
# 155        8.0
# 156       64.0
#
# [157 rows x 21 columns]

# %%
demo_perso[["Gender","Extraversion","Intuition","Thinking","Judging","Assertive"]].groupby("Gender").mean()
# Out:
#                    Extraversion  Intuition   Thinking    Judging  Assertive
# Gender
# Female                55.441176  56.794118  44.735294  56.705882  42.058824
# Male                  53.866667  51.533333  49.333333  52.900000  49.933333
# Prefer not to say     22.000000  48.000000  59.000000  75.000000  56.000000

# %%
men_women_pers_data = demo_perso[["Gender","Extraversion","Intuition","Thinking","Judging","Assertive"]]
men_pers_data = men_women_pers_data[men_women_pers_data['Gender']== 'Male']
women_pers_data = men_women_pers_data[men_women_pers_data['Gender']== 'Female']

men_pers_data
# Out:
#    Gender  Extraversion  Intuition  Thinking  Judging  Assertive
# 1    Male            48         41        57       49         36
# 2    Male            74         48        43       29         63
# 4    Male            56         68        27       47         49
# 6    Male            38         63        59       54         51
# 8    Male            56         73        53       47         37
# 9    Male            74         42        36       68         18
# 10   Male            61         29        66       72         75
# 11   Male            52         69        49       67         42
# 15   Male            73         66        33       33         22
# 17   Male             6          7         7        7          6
# 18   Male            46         62        72       21         60
# 21   Male            71         49        43       94         93
# 22   Male            60         49        40       65         69
# 26   Male            71         66        65       31         81
# 31   Male            74         51        52       68         83
# 33   Male            29         48        41       72         19
# 35   Male            54         49        58       40         58
# 37   Male            36         59        40       74         42
# 39   Male            57         51        39       61         33
# 44   Male            81         80        64       60         56
# 45   Male            32         45        35       49         36
# 46   Male            71         61        41       72         74
# 47   Male            63         42        43       42         49
# 48   Male            45         43        57       53         56
# 49   Male            28         66        49       57         57
# 50   Male            17         38        82       29         69
# 51   Male            63         51        52       51         51
# 52   Male            82         52        71       49         40
# 56   Male            73         54        57       82         63
# 62   Male            25         24        49       44         10

# %%
from scipy import stats

# %%
# Sample data
men_extra = men_pers_data["Extraversion"]
women_extra = women_pers_data["Extraversion"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(men_extra, women_extra)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -0.3393028060842544
# p-value: 0.7355282621182396

# %%
# Sample data
men_extra = men_pers_data["Intuition"]
women_extra = women_pers_data["Intuition"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(men_extra, women_extra)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -1.555185701264877
# p-value: 0.12499206419271792

# %%
# Sample data
men_extra = men_pers_data["Thinking"]
women_extra = women_pers_data["Thinking"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(men_extra, women_extra)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 1.2382428472318803
# p-value: 0.2202941804667836

# %%
# Sample data
men_extra = men_pers_data["Judging"]
women_extra = women_pers_data["Judging"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(men_extra, women_extra)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -0.8432640636954141
# p-value: 0.4023224183733458

# %%
# Sample data
men_extra = men_pers_data["Assertive"]
women_extra = women_pers_data["Assertive"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(men_extra, women_extra)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 1.5731000781489826
# p-value: 0.12078529207317402

# %%
demo_perso[demo_perso["Last 4 digits of your mobile (0000 to 9999)"] == 2785]
# Out:
#     Age (in years)  CAO Points (100 to 600)  \
# 17            20.0                    521.0
#
#     Daily travel to DCU (in km, 0 if on-campus)  \
# 17                                          5.0
#
#     Average year 1 exam result (as %)  Seat row in class Gender  \
# 17                               68.0                4.0   Male
#
#     Number of older siblings  Number of younger siblings  \
# 17                         1                           0
#
#     Old Dublin postcode (0 if outside Dublin)  Height (in cm)  ...  \
# 17                                          9           178.0  ...
#
#     Eye colour Hair colour Last 4 digits of your mobile (0000 to 9999)  \
# 17        Blue         Red                                        2785
#
#     Star sign Shoe size  Extraversion  Intuition  Thinking  Judging  Assertive
# 17      Libra       9.0             6          7         7        7          6
#
# [1 rows x 21 columns]

# %%
round(demo_perso.describe(),2)
# Out:
#        Age (in years)  CAO Points (100 to 600)  \
# count           65.00                    65.00
# mean            21.62                   499.38
# std              4.97                    69.66
# min             18.00                   130.00
# 25%             20.00                   491.00
# 50%             21.00                   510.00
# 75%             22.00                   545.00
# max             58.00                   578.00
#
#        Daily travel to DCU (in km, 0 if on-campus)  \
# count                                        65.00
# mean                                         11.08
# std                                          18.81
# min                                           0.00
# 25%                                           2.00
# 50%                                           4.80
# 75%                                          10.00
# max                                         103.00
#
#        Average year 1 exam result (as %)  Seat row in class  \
# count                              65.00              65.00
# mean                               68.59               6.05
# std                                 9.34               2.85
# min                                42.00               1.00
# 25%                                65.00               4.00
# 50%                                68.00               5.00
# 75%                                73.00               8.00
# max                                95.00              12.00
#
#        Number of older siblings  Number of younger siblings  \
# count                     65.00                       65.00
# mean                       1.20                        0.86
# std                        1.06                        0.92
# min                        0.00                        0.00
# 25%                        0.00                        0.00
# 50%                        1.00                        1.00
# 75%                        2.00                        1.00
# max                        4.00                        4.00
#
#        Old Dublin postcode (0 if outside Dublin)  Height (in cm)  \
# count                                      65.00           65.00
# mean                                        4.72          175.58
# std                                         5.66           10.54
# min                                         0.00          153.00
# 25%                                         0.00          168.00
# 50%                                         1.00          175.00
# 75%                                         9.00          182.00
# max                                        22.00          197.00
#
#        Weight (in kg)  Last 4 digits of your mobile (0000 to 9999)  Shoe size  \
# count           65.00                                        65.00      65.00
# mean            71.65                                      4568.45       7.79
# std             12.64                                      2761.25       2.47
# min             51.00                                       111.00       3.00
# 25%             62.50                                      2228.00       6.00
# 50%             70.00                                      4397.00       8.00
# 75%             80.00                                      6984.00      10.00
# max            104.00                                      9898.00      13.00
#
#        Extraversion  Intuition  Thinking  Judging  Assertive
# count          65.0      65.00     65.00    65.00      65.00
# mean           54.2      54.23     47.08    55.23      45.91
# std            18.7      13.57     14.85    18.01      20.10
# min             6.0       7.00      7.00     7.00       6.00
# 25%            42.0      48.00     36.00    44.00      31.00
# 50%            57.0      55.00     47.00    57.00      44.00
# 75%            66.0      66.00     58.00    68.00      60.00
# max            88.0      81.00     82.00    94.00      93.00

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demo_perso[['Weight (in kg)', 'Shoe size']]
yDf = demo_perso['Height (in cm)']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin.score(X_test, y_test))
print(reg_lin.coef_)
#print(reg_lin.predict([[20,600]]))
# Out:
# 0.881695197173823
# [0.55 1.33]

# %%
demo_perso["Total Siblings"] = demo_perso["Number of older siblings"] + demo_perso["Number of younger siblings"]
demo_perso
# Out:
#     Age (in years)  CAO Points (100 to 600)  \
# 0             22.0                    505.0
# 1             19.0                    543.0
# 2             21.0                    557.0
# 3             22.0                    397.0
# 4             25.0                    532.0
# ..             ...                      ...
# 60            21.0                    565.0
# 61            20.0                    520.0
# 62            20.0                    510.0
# 63            23.0                    490.0
# 64            22.0                    500.0
#
#     Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                          11.6
# 1                                          10.0
# 2                                          15.0
# 3                                           5.0
# 4                                          20.0
# ..                                          ...
# 60                                          7.0
# 61                                          7.0
# 62                                         60.0
# 63                                          7.0
# 64                                          4.0
#
#     Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                                68.0                7.0  Female
# 1                                71.0                2.0    Male
# 2                                50.5               10.0    Male
# 3                                65.0                5.0  Female
# 4                                72.0                8.0    Male
# ..                                ...                ...     ...
# 60                               71.0                3.0  Female
# 61                               62.0                8.0  Female
# 62                               65.0                5.0    Male
# 63                               70.0                4.0  Female
# 64                               65.0                4.0  Female
#
#     Number of older siblings  Number of younger siblings  \
# 0                          0                           1
# 1                          0                           1
# 2                          2                           0
# 3                          2                           0
# 4                          1                           1
# ..                       ...                         ...
# 60                         2                           1
# 61                         0                           2
# 62                         1                           1
# 63                         0                           3
# 64                         0                           3
#
#     Old Dublin postcode (0 if outside Dublin)  Height (in cm)  ...  \
# 0                                           0           155.0  ...
# 1                                          13           187.0  ...
# 2                                          15           178.0  ...
# 3                                           0           153.0  ...
# 4                                          22           192.0  ...
# ..                                        ...             ...  ...
# 60                                         14           170.0  ...
# 61                                          7           165.0  ...
# 62                                          0           184.0  ...
# 63                                          7           173.0  ...
# 64                                          0           177.0  ...
#
#     Hair colour Last 4 digits of your mobile (0000 to 9999)    Star sign  \
# 0         Brown                                        7181          Leo
# 1           Red                                         838       Taurus
# 2         Brown                                        4397        Aries
# 3         Brown                                        8626  Sagittarius
# 4         Brown                                        4768     Aquarius
# ..          ...                                         ...          ...
# 60        Black                                        1699        Libra
# 61        Black                                        5289       Taurus
# 62        Brown                                        5317        Libra
# 63       Blonde                                        4602     Aquarius
# 64        Brown                                        6402          Leo
#
#     Shoe size Extraversion  Intuition  Thinking  Judging  Assertive  \
# 0         4.0           32         62        23       35         31
# 1         9.0           48         41        57       49         36
# 2         7.0           74         48        43       29         63
# 3         5.0           25         55        43       61         44
# 4        12.0           56         68        27       47         49
# ..        ...          ...        ...       ...      ...        ...
# 60        6.0           64         69        63       58         60
# 61        5.0           61         55        66       49         67
# 62       10.0           25         24        49       44         10
# 63        7.0           29         23        32       60         32
# 64        7.0           78         68        53       71         63
#
#     Total Siblings
# 0                1
# 1                1
# 2                2
# 3                2
# 4                2
# ..             ...
# 60               3
# 61               2
# 62               2
# 63               3
# 64               3
#
# [65 rows x 22 columns]

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demo_perso[['Total Siblings']]
yDf = demo_perso['Average year 1 exam result (as %)']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin.score(X_test, y_test))
print(reg_lin.coef_)
# Out:
# -0.010667440116289617
# [1.35]

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demo_perso[['Number of older siblings', "Number of younger siblings"]]
yDf = demo_perso['Average year 1 exam result (as %)']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin.score(X_test, y_test))
print(reg_lin.coef_)
# Out:
# -0.014494104692228449
# [1.23 1.98]

# %%
plt.scatter(demo_perso["Seat row in class"], demo_perso["Average year 1 exam result (as %)"])
plt.title("Relation between Seat Row and Year 1 Exam Results")
plt.xlabel("Seat Row")
plt.ylabel("Year 1 Exam Results")
plt.show()

# %%
corr_matrix = demo_perso.corr()
corr_matrix
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_912\3046399116.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = demo_perso.corr()
#                                              Age (in years)  \
# Age (in years)                                     1.000000
# CAO Points (100 to 600)                           -0.111906
# Daily travel to DCU (in km, 0 if on-campus)        0.278992
# Average year 1 exam result (as %)                  0.049233
# Seat row in class                                  0.245725
# Number of older siblings                           0.050210
# Number of younger siblings                         0.392603
# Old Dublin postcode (0 if outside Dublin)         -0.001067
# Height (in cm)                                     0.293201
# Weight (in kg)                                     0.369727
# Last 4 digits of your mobile (0000 to 9999)        0.203842
# Shoe size                                          0.167851
# Extraversion                                      -0.210533
# Intuition                                         -0.107456
# Thinking                                          -0.103695
# Judging                                            0.009903
# Assertive                                         -0.018023
# Total Siblings                                     0.370155
#
#                                              CAO Points (100 to 600)  \
# Age (in years)                                             -0.111906
# CAO Points (100 to 600)                                     1.000000
# Daily travel to DCU (in km, 0 if on-campus)                 0.130395
# Average year 1 exam result (as %)                           0.255457
# Seat row in class                                           0.024599
# Number of older siblings                                    0.018560
# Number of younger siblings                                  0.123719
# Old Dublin postcode (0 if outside Dublin)                  -0.000835
# Height (in cm)                                             -0.107463
# Weight (in kg)                                             -0.195651
# Last 4 digits of your mobile (0000 to 9999)                -0.167423
# Shoe size                                                   0.048486
# Extraversion                                                0.124650
# Intuition                                                   0.140995
# Thinking                                                   -0.170900
# Judging                                                    -0.166736
# Assertive                                                   0.048867
# Total Siblings                                              0.119253
#
#                                              Daily travel to DCU (in km, 0 if on-campus)  \
# Age (in years)                                                                  0.278992
# CAO Points (100 to 600)                                                         0.130395
# Daily travel to DCU (in km, 0 if on-campus)                                     1.000000
# Average year 1 exam result (as %)                                               0.102092
# Seat row in class                                                               0.179545
# Number of older siblings                                                        0.271920
# Number of younger siblings                                                      0.204547
# Old Dublin postcode (0 if outside Dublin)                                      -0.094651
# Height (in cm)                                                                  0.055816
# Weight (in kg)                                                                  0.068105
# Last 4 digits of your mobile (0000 to 9999)                                     0.027413
# Shoe size                                                                       0.032775
# Extraversion                                                                   -0.137154
# Intuition                                                                      -0.025023
# Thinking                                                                        0.001853
# Judging                                                                         0.092695
# Assertive                                                                      -0.014123
# Total Siblings                                                                  0.427008
#
#                                              Average year 1 exam result (as %)  \
# Age (in years)                                                        0.049233
# CAO Points (100 to 600)                                               0.255457
# Daily travel to DCU (in km, 0 if on-campus)                           0.102092
# Average year 1 exam result (as %)                                     1.000000
# Seat row in class                                                    -0.158280
# Number of older siblings                                              0.046895
# Number of younger siblings                                            0.103791
# Old Dublin postcode (0 if outside Dublin)                            -0.093189
# Height (in cm)                                                        0.032875
# Weight (in kg)                                                        0.084848
# Last 4 digits of your mobile (0000 to 9999)                          -0.001629
# Shoe size                                                             0.017639
# Extraversion                                                          0.100564
# Intuition                                                            -0.030695
# Thinking                                                              0.064716
# Judging                                                               0.084867
# Assertive                                                             0.342285
# Total Siblings                                                        0.129891
#
#                                              Seat row in class  \
# Age (in years)                                        0.245725
# CAO Points (100 to 600)                               0.024599
# Daily travel to DCU (in km, 0 if on-campus)           0.179545
# Average year 1 exam result (as %)                    -0.158280
# Seat row in class                                     1.000000
# Number of older siblings                              0.125649
# Number of younger siblings                            0.050293
# Old Dublin postcode (0 if outside Dublin)             0.112980
# Height (in cm)                                       -0.040410
# Weight (in kg)                                        0.024063
# Last 4 digits of your mobile (0000 to 9999)           0.208703
# Shoe size                                            -0.111853
# Extraversion                                         -0.119409
# Intuition                                             0.057432
# Thinking                                             -0.034025
# Judging                                              -0.007814
# Assertive                                             0.009341
# Total Siblings                                        0.161005
#
#                                              Number of older siblings  \
# Age (in years)                                               0.050210
# CAO Points (100 to 600)                                      0.018560
# Daily travel to DCU (in km, 0 if on-campus)                  0.271920
# Average year 1 exam result (as %)                            0.046895
# Seat row in class                                            0.125649
# Number of older siblings                                     1.000000
# Number of younger siblings                                  -0.371890
# Old Dublin postcode (0 if outside Dublin)                    0.009338
# Height (in cm)                                               0.166444
# Weight (in kg)                                               0.066240
# Last 4 digits of your mobile (0000 to 9999)                  0.072676
# Shoe size                                                    0.039901
# Extraversion                                                -0.035831
# Intuition                                                    0.142887
# Thinking                                                    -0.141500
# Judging                                                      0.241466
# Assertive                                                    0.003801
# Total Siblings                                               0.647471
#
#                                              Number of younger siblings  \
# Age (in years)                                                 0.392603
# CAO Points (100 to 600)                                        0.123719
# Daily travel to DCU (in km, 0 if on-campus)                    0.204547
# Average year 1 exam result (as %)                              0.103791
# Seat row in class                                              0.050293
# Number of older siblings                                      -0.371890
# Number of younger siblings                                     1.000000
# Old Dublin postcode (0 if outside Dublin)                      0.067753
# Height (in cm)                                                -0.027080
# Weight (in kg)                                                 0.063233
# Last 4 digits of your mobile (0000 to 9999)                    0.095038
# Shoe size                                                     -0.006008
# Extraversion                                                   0.140254
# Intuition                                                      0.023966
# Thinking                                                       0.097259
# Judging                                                       -0.090814
# Assertive                                                      0.107030
# Total Siblings                                                 0.466644
#
#                                              Old Dublin postcode (0 if outside Dublin)  \
# Age (in years)                                                               -0.001067
# CAO Points (100 to 600)                                                      -0.000835
# Daily travel to DCU (in km, 0 if on-campus)                                  -0.094651
# Average year 1 exam result (as %)                                            -0.093189
# Seat row in class                                                             0.112980
# Number of older siblings                                                      0.009338
# Number of younger siblings                                                    0.067753
# Old Dublin postcode (0 if outside Dublin)                                     1.000000
# Height (in cm)                                                                0.140451
# Weight (in kg)                                                                0.116377
# Last 4 digits of your mobile (0000 to 9999)                                  -0.194874
# Shoe size                                                                     0.182025
# Extraversion                                                                 -0.184508
# Intuition                                                                    -0.028834
# Thinking                                                                     -0.065337
# Judging                                                                      -0.165118
# Assertive                                                                    -0.045800
# Total Siblings                                                                0.064520
#
#                                              Height (in cm)  Weight (in kg)  \
# Age (in years)                                     0.293201        0.369727
# CAO Points (100 to 600)                           -0.107463       -0.195651
# Daily travel to DCU (in km, 0 if on-campus)        0.055816        0.068105
# Average year 1 exam result (as %)                  0.032875        0.084848
# Seat row in class                                 -0.040410        0.024063
# Number of older siblings                           0.166444        0.066240
# Number of younger siblings                        -0.027080        0.063233
# Old Dublin postcode (0 if outside Dublin)          0.140451        0.116377
# Height (in cm)                                     1.000000        0.854217
# Weight (in kg)                                     0.854217        1.000000
# Last 4 digits of your mobile (0000 to 9999)        0.084922        0.217487
# Shoe size                                          0.776189        0.665701
# Extraversion                                      -0.077607       -0.084623
# Intuition                                         -0.259990       -0.237646
# Thinking                                           0.215121        0.110123
# Judging                                            0.036410       -0.047963
# Assertive                                          0.162852        0.085172
# Total Siblings                                     0.136353        0.115025
#
#                                              Last 4 digits of your mobile (0000 to 9999)  \
# Age (in years)                                                                  0.203842
# CAO Points (100 to 600)                                                        -0.167423
# Daily travel to DCU (in km, 0 if on-campus)                                     0.027413
# Average year 1 exam result (as %)                                              -0.001629
# Seat row in class                                                               0.208703
# Number of older siblings                                                        0.072676
# Number of younger siblings                                                      0.095038
# Old Dublin postcode (0 if outside Dublin)                                      -0.194874
# Height (in cm)                                                                  0.084922
# Weight (in kg)                                                                  0.217487
# Last 4 digits of your mobile (0000 to 9999)                                     1.000000
# Shoe size                                                                      -0.155523
# Extraversion                                                                   -0.140279
# Intuition                                                                      -0.067250
# Thinking                                                                        0.031063
# Judging                                                                         0.270103
# Assertive                                                                       0.212492
# Total Siblings                                                                  0.147268
#
#                                              Shoe size  Extraversion  \
# Age (in years)                                0.167851     -0.210533
# CAO Points (100 to 600)                       0.048486      0.124650
# Daily travel to DCU (in km, 0 if on-campus)   0.032775     -0.137154
# Average year 1 exam result (as %)             0.017639      0.100564
# Seat row in class                            -0.111853     -0.119409
# Number of older siblings                      0.039901     -0.035831
# Number of younger siblings                   -0.006008      0.140254
# Old Dublin postcode (0 if outside Dublin)     0.182025     -0.184508
# Height (in cm)                                0.776189     -0.077607
# Weight (in kg)                                0.665701     -0.084623
# Last 4 digits of your mobile (0000 to 9999)  -0.155523     -0.140279
# Shoe size                                     1.000000     -0.098014
# Extraversion                                 -0.098014      1.000000
# Intuition                                    -0.146499      0.416846
# Thinking                                      0.145928      0.177322
# Judging                                      -0.188311      0.101727
# Assertive                                     0.001971      0.310762
# Total Siblings                                0.033085      0.081006
#
#                                              Intuition  Thinking   Judging  \
# Age (in years)                               -0.107456 -0.103695  0.009903
# CAO Points (100 to 600)                       0.140995 -0.170900 -0.166736
# Daily travel to DCU (in km, 0 if on-campus)  -0.025023  0.001853  0.092695
# Average year 1 exam result (as %)            -0.030695  0.064716  0.084867
# Seat row in class                             0.057432 -0.034025 -0.007814
# Number of older siblings                      0.142887 -0.141500  0.241466
# Number of younger siblings                    0.023966  0.097259 -0.090814
# Old Dublin postcode (0 if outside Dublin)    -0.028834 -0.065337 -0.165118
# Height (in cm)                               -0.259990  0.215121  0.036410
# Weight (in kg)                               -0.237646  0.110123 -0.047963
# Last 4 digits of your mobile (0000 to 9999)  -0.067250  0.031063  0.270103
# Shoe size                                    -0.146499  0.145928 -0.188311
# Extraversion                                  0.416846  0.177322  0.101727
# Intuition                                     1.000000  0.143687  0.089028
# Thinking                                      0.143687  1.000000  0.095426
# Judging                                       0.089028  0.095426  1.000000
# Assertive                                     0.123645  0.472886  0.244493
# Total Siblings                                0.155816 -0.054972  0.155509
#
#                                              Assertive  Total Siblings
# Age (in years)                               -0.018023        0.370155
# CAO Points (100 to 600)                       0.048867        0.119253
# Daily travel to DCU (in km, 0 if on-campus)  -0.014123        0.427008
# Average year 1 exam result (as %)             0.342285        0.129891
# Seat row in class                             0.009341        0.161005
# Number of older siblings                      0.003801        0.647471
# Number of younger siblings                    0.107030        0.466644
# Old Dublin postcode (0 if outside Dublin)    -0.045800        0.064520
# Height (in cm)                                0.162852        0.136353
# Weight (in kg)                                0.085172        0.115025
# Last 4 digits of your mobile (0000 to 9999)   0.212492        0.147268
# Shoe size                                     0.001971        0.033085
# Extraversion                                  0.310762        0.081006
# Intuition                                     0.123645        0.155816
# Thinking                                      0.472886       -0.054972
# Judging                                       0.244493        0.155509
# Assertive                                     1.000000        0.091490
# Total Siblings                                0.091490        1.000000

# %%
tpllst = []
for i in range(0,18):
    for j in range(0,18):
        if corr_matrix.iloc[i,j]>0.6 and corr_matrix.iloc[i,j]<1.0:
            tpllst.append((corr_matrix.index[i], corr_matrix.index[j], corr_matrix.iloc[i,j]))
tpllst
# Out:
# [('Number of older siblings', 'Total Siblings', 0.647470523325822),
#  ('Height (in cm)', 'Weight (in kg)', 0.8542174262263178),
#  ('Height (in cm)', 'Shoe size', 0.776188771867279),
#  ('Weight (in kg)', 'Height (in cm)', 0.8542174262263178),
#  ('Weight (in kg)', 'Shoe size', 0.6657007827143666),
#  ('Shoe size', 'Height (in cm)', 0.776188771867279),
#  ('Shoe size', 'Weight (in kg)', 0.6657007827143666),
#  ('Total Siblings', 'Number of older siblings', 0.647470523325822)]

# %%
demo_perso["Eye colour"].unique()
# Out:
# array(['Blue', 'Green', 'Brown'], dtype=object)

# %%
demo_perso["Hair colour"].unique()
# Out:
# array(['Brown', 'Red', 'Blonde', 'Black'], dtype=object)

# %%
demo_perso["Star sign"].unique()
# Out:
# array(['Leo', 'Taurus', 'Aries', 'Sagittarius', 'Aquarius', 'Scorpio',
#        'Virgo', 'Gemini', 'Capricorn', 'Libra', 'Pices', 'Cancer'],
#       dtype=object)

# %%
len(demo_perso["Star sign"].unique())
# Out:
# 12

# %%
demo_perso["Star sign"].value_counts()
# Out:
# Taurus         10
# Leo             9
# Aquarius        7
# Gemini          7
# Sagittarius     6
# Scorpio         5
# Libra           5
# Virgo           4
# Capricorn       4
# Pices           4
# Aries           3
# Cancer          1
# Name: Star sign, dtype: int64

# %%
#For the hair colour and eye colour, labe encoding can be used to be ablre to perform analysis with the data using bot of them with an ordinal scale from light to dark

# %%
encoded_dict = {'Blonde': 0, 'Red': 1, 'Brown': 2, "Black":3}
demo_perso["Hair Colour Encoded"] = demo_perso["Hair colour"].map(encoded_dict)
demo_perso
# Out:
#     Age (in years)  CAO Points (100 to 600)  \
# 0             22.0                    505.0
# 1             19.0                    543.0
# 2             21.0                    557.0
# 3             22.0                    397.0
# 4             25.0                    532.0
# ..             ...                      ...
# 60            21.0                    565.0
# 61            20.0                    520.0
# 62            20.0                    510.0
# 63            23.0                    490.0
# 64            22.0                    500.0
#
#     Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                          11.6
# 1                                          10.0
# 2                                          15.0
# 3                                           5.0
# 4                                          20.0
# ..                                          ...
# 60                                          7.0
# 61                                          7.0
# 62                                         60.0
# 63                                          7.0
# 64                                          4.0
#
#     Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                                68.0                7.0  Female
# 1                                71.0                2.0    Male
# 2                                50.5               10.0    Male
# 3                                65.0                5.0  Female
# 4                                72.0                8.0    Male
# ..                                ...                ...     ...
# 60                               71.0                3.0  Female
# 61                               62.0                8.0  Female
# 62                               65.0                5.0    Male
# 63                               70.0                4.0  Female
# 64                               65.0                4.0  Female
#
#     Number of older siblings  Number of younger siblings  \
# 0                          0                           1
# 1                          0                           1
# 2                          2                           0
# 3                          2                           0
# 4                          1                           1
# ..                       ...                         ...
# 60                         2                           1
# 61                         0                           2
# 62                         1                           1
# 63                         0                           3
# 64                         0                           3
#
#     Old Dublin postcode (0 if outside Dublin)  Height (in cm)  ...  \
# 0                                           0           155.0  ...
# 1                                          13           187.0  ...
# 2                                          15           178.0  ...
# 3                                           0           153.0  ...
# 4                                          22           192.0  ...
# ..                                        ...             ...  ...
# 60                                         14           170.0  ...
# 61                                          7           165.0  ...
# 62                                          0           184.0  ...
# 63                                          7           173.0  ...
# 64                                          0           177.0  ...
#
#     Last 4 digits of your mobile (0000 to 9999)    Star sign Shoe size  \
# 0                                          7181          Leo       4.0
# 1                                           838       Taurus       9.0
# 2                                          4397        Aries       7.0
# 3                                          8626  Sagittarius       5.0
# 4                                          4768     Aquarius      12.0
# ..                                          ...          ...       ...
# 60                                         1699        Libra       6.0
# 61                                         5289       Taurus       5.0
# 62                                         5317        Libra      10.0
# 63                                         4602     Aquarius       7.0
# 64                                         6402          Leo       7.0
#
#     Extraversion Intuition  Thinking  Judging  Assertive  Total Siblings  \
# 0             32        62        23       35         31               1
# 1             48        41        57       49         36               1
# 2             74        48        43       29         63               2
# 3             25        55        43       61         44               2
# 4             56        68        27       47         49               2
# ..           ...       ...       ...      ...        ...             ...
# 60            64        69        63       58         60               3
# 61            61        55        66       49         67               2
# 62            25        24        49       44         10               2
# 63            29        23        32       60         32               3
# 64            78        68        53       71         63               3
#
#     Hair Colour Encoded
# 0                     2
# 1                     1
# 2                     2
# 3                     2
# 4                     2
# ..                  ...
# 60                    3
# 61                    3
# 62                    2
# 63                    0
# 64                    2
#
# [65 rows x 23 columns]

# %%
encoded_dict2 = {'Blue': 0, 'Green': 1, 'Brown': 2}
demo_perso["Eye Colour Encoded"] = demo_perso["Eye colour"].map(encoded_dict2)
demo_perso
# Out:
#     Age (in years)  CAO Points (100 to 600)  \
# 0             22.0                    505.0
# 1             19.0                    543.0
# 2             21.0                    557.0
# 3             22.0                    397.0
# 4             25.0                    532.0
# ..             ...                      ...
# 60            21.0                    565.0
# 61            20.0                    520.0
# 62            20.0                    510.0
# 63            23.0                    490.0
# 64            22.0                    500.0
#
#     Daily travel to DCU (in km, 0 if on-campus)  \
# 0                                          11.6
# 1                                          10.0
# 2                                          15.0
# 3                                           5.0
# 4                                          20.0
# ..                                          ...
# 60                                          7.0
# 61                                          7.0
# 62                                         60.0
# 63                                          7.0
# 64                                          4.0
#
#     Average year 1 exam result (as %)  Seat row in class  Gender  \
# 0                                68.0                7.0  Female
# 1                                71.0                2.0    Male
# 2                                50.5               10.0    Male
# 3                                65.0                5.0  Female
# 4                                72.0                8.0    Male
# ..                                ...                ...     ...
# 60                               71.0                3.0  Female
# 61                               62.0                8.0  Female
# 62                               65.0                5.0    Male
# 63                               70.0                4.0  Female
# 64                               65.0                4.0  Female
#
#     Number of older siblings  Number of younger siblings  \
# 0                          0                           1
# 1                          0                           1
# 2                          2                           0
# 3                          2                           0
# 4                          1                           1
# ..                       ...                         ...
# 60                         2                           1
# 61                         0                           2
# 62                         1                           1
# 63                         0                           3
# 64                         0                           3
#
#     Old Dublin postcode (0 if outside Dublin)  Height (in cm)  ...  \
# 0                                           0           155.0  ...
# 1                                          13           187.0  ...
# 2                                          15           178.0  ...
# 3                                           0           153.0  ...
# 4                                          22           192.0  ...
# ..                                        ...             ...  ...
# 60                                         14           170.0  ...
# 61                                          7           165.0  ...
# 62                                          0           184.0  ...
# 63                                          7           173.0  ...
# 64                                          0           177.0  ...
#
#       Star sign Shoe size Extraversion  Intuition Thinking  Judging  \
# 0           Leo       4.0           32         62       23       35
# 1        Taurus       9.0           48         41       57       49
# 2         Aries       7.0           74         48       43       29
# 3   Sagittarius       5.0           25         55       43       61
# 4      Aquarius      12.0           56         68       27       47
# ..          ...       ...          ...        ...      ...      ...
# 60        Libra       6.0           64         69       63       58
# 61       Taurus       5.0           61         55       66       49
# 62        Libra      10.0           25         24       49       44
# 63     Aquarius       7.0           29         23       32       60
# 64          Leo       7.0           78         68       53       71
#
#     Assertive  Total Siblings  Hair Colour Encoded  Eye Colour Encoded
# 0          31               1                    2                   0
# 1          36               1                    1                   0
# 2          63               2                    2                   1
# 3          44               2                    2                   2
# 4          49               2                    2                   1
# ..        ...             ...                  ...                 ...
# 60         60               3                    3                   0
# 61         67               2                    3                   0
# 62         10               2                    2                   0
# 63         32               3                    0                   1
# 64         63               3                    2                   0
#
# [65 rows x 24 columns]

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demo_perso[['Hair Colour Encoded']]
yDf = demo_perso['Eye Colour Encoded']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin.score(X_test, y_test))
print(reg_lin.coef_)
# Out:
# 0.013984651964982997
# [0.06]

# %%
demo_perso[['Hair Colour Encoded', 'Eye Colour Encoded']].corr()
# Out:
#                      Hair Colour Encoded  Eye Colour Encoded
# Hair Colour Encoded             1.000000            0.138736
# Eye Colour Encoded              0.138736            1.000000

# %%
# import libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demo_perso[["Extraversion", "Intuition", "Thinking", "Judging", "Assertive"]]
yDf = demo_perso['CAO Points (100 to 600)']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin.score(X_test, y_test))
print(reg_lin.coef_)
# Out:
# -0.7366421262828751
# [ 0.28  1.02 -1.26 -0.95  0.53]

# %%
round(demo_perso[['Star sign', "Extraversion", "Intuition", "Thinking", "Judging", "Assertive"]].groupby("Star sign").mean(),2)
# Out:
#              Extraversion  Intuition  Thinking  Judging  Assertive
# Star sign
# Aquarius            53.29      55.29     47.71    48.86      38.57
# Aries               56.67      46.00     46.00    57.33      45.67
# Cancer              64.00      49.00     36.00    39.00      51.00
# Capricorn           54.75      52.75     43.00    69.75      47.00
# Gemini              58.43      50.57     54.14    55.57      50.14
# Leo                 52.89      60.67     50.67    52.67      50.00
# Libra               38.20      40.80     40.60    44.20      27.60
# Pices               56.00      68.75     47.00    52.75      44.50
# Sagittarius         50.67      57.33     39.83    58.50      55.00
# Scorpio             48.40      54.80     46.00    66.00      49.00
# Taurus              62.80      53.40     47.80    53.30      51.30
# Virgo               55.75      52.25     51.75    62.25      33.25

# %%
demo_perso[['Star sign', "Extraversion", "Intuition", "Thinking", "Judging", "Assertive"]].groupby("Star sign").max()
# Out:
#              Extraversion  Intuition  Thinking  Judging  Assertive
# Star sign
# Aquarius               81         73        72       67         60
# Aries                  74         48        59       75         63
# Cancer                 64         49        36       39         51
# Capricorn              74         69        52       72         83
# Gemini                 73         71        66       82         75
# Leo                    82         68        82       75         69
# Libra                  64         69        63       63         60
# Pices                  81         80        66       74         74
# Sagittarius            79         66        48       74         92
# Scorpio                71         81        71       94         93
# Taurus                 88         68        66       89         81
# Virgo                  84         72        62       83         49

# %%
taur_extra = demo_perso[demo_perso["Star sign"] == "Taurus"]["Extraversion"]
taur_extra
# Out:
# 1     48
# 16    52
# 22    60
# 26    71
# 30    60
# 34    88
# 42    61
# 51    63
# 59    64
# 61    61
# Name: Extraversion, dtype: int64

# %%
libra_extra = demo_perso[demo_perso["Star sign"] == "Libra"]["Extraversion"]
libra_extra
# Out:
# 17     6
# 23    64
# 45    32
# 60    64
# 62    25
# Name: Extraversion, dtype: int64

# %%
# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(taur_extra, libra_extra)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 2.6831956256764093
# p-value: 0.01878615465751587

# %%
pices_int = demo_perso[demo_perso["Star sign"] == "Pices"]["Intuition"]
libra_int = demo_perso[demo_perso["Star sign"] == "Libra"]["Intuition"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(pices_int, libra_int)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 2.0969636976039263
# p-value: 0.07420312638106841

# %%
gemini_think = demo_perso[demo_perso["Star sign"] == "Gemini"]["Thinking"]
sagi_think = demo_perso[demo_perso["Star sign"] == "Sagittarius"]["Thinking"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(gemini_think, sagi_think)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 2.648137783276497
# p-value: 0.022661602027265002

# %%
capri_judg = demo_perso[demo_perso["Star sign"] == "Capricorn"]["Judging"]
libra_judg = demo_perso[demo_perso["Star sign"] == "Libra"]["Judging"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(capri_judg, libra_judg)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 2.26949781940611
# p-value: 0.05752006903890409

# %%
virgo_asser = demo_perso[demo_perso["Star sign"] == "Virgo"]["Assertive"]
sagi_asser = demo_perso[demo_perso["Star sign"] == "Sagittarius"]["Assertive"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(virgo_asser, sagi_asser)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -1.759236876585312
# p-value: 0.11658219714203413

# %%
plt.plot(taur_extra, marker = "s", color = "green", linestyle = "-", linewidth = 1.5, label = "Taurus")
plt.plot(libra_extra, marker = "s", color = "orange", linestyle = "-", linewidth = 1.5, label = "Libra")
plt.title("Extraversion Taurus and Libra")
plt.xlabel("Observations Index")
plt.ylabel("Personality Score")
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

# Plot the first line graph on the first subplot
ax1.plot(range(0,10), taur_extra, color='green', label='Taurus')
ax1.set_xlabel('Observations')
ax1.set_ylabel('Personality Score')
ax1.set_title('Taurus Extraversion')
ax1.legend()
ax1.set_ylim(0,100)
ax1.set_xticks([])

# Plot the second line graph on the second subplot
ax2.plot(range(0,5), libra_extra, color='orange', label='Libra')
ax2.set_xlabel('Observations')
ax2.set_ylabel('Personality Score')
ax2.set_title('Libra Extraversion')
ax2.legend()
ax2.set_ylim(0,100)
ax2.set_xticks([])

plt.tight_layout()

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

# Plot the first line graph on the first subplot
ax1.plot(range(0,7), gemini_think, color='blue', label='Gemini')
ax1.set_xlabel('Observations')
ax1.set_ylabel('Personality Score')
ax1.set_title('Gemini Extraversion')
ax1.legend()
ax1.set_ylim(0,100)
ax1.set_xticks([])

# Plot the second line graph on the second subplot
ax2.plot(range(0,6), sagi_think, color='pink', label='Sagittarius')
ax2.set_xlabel('Observations')
ax2.set_ylabel('Personality Score')
ax2.set_title('Sagittarius Extraversion')
ax2.legend()
ax2.set_ylim(0,100)
ax2.set_xticks([])

plt.tight_layout()

plt.show()

# %%
corr_matrix

# %%
import seaborn as sns

# %%
sns.heatmap(correlations)
# Out:
# <Axes: >

# %%
plt.scatter(demo_perso["Shoe size"], demo_perso["Height (in cm)"])
plt.title("Relation between Shoe Size and Height")
plt.xlabel("Shoe Size")
plt.ylabel("Height")
plt.show()

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demo_perso[['Weight (in kg)']]
yDf = demo_perso['Height (in cm)']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin_weight = LinearRegression().fit(X_train, y_train)
intercept_weight = reg_lin_weight.intercept_ 

#getting the accuracy
print(reg_lin_weight.score(X_test, y_test))
print(reg_lin_weight.coef_)
print(intercept_weight)

# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = demo_perso[['Shoe size']]
yDf = demo_perso['Height (in cm)']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin_shoe = LinearRegression().fit(X_train, y_train)
intercept_shoe = reg_lin_shoe.intercept_ 

#getting the accuracy
print(reg_lin_shoe.score(X_test, y_test))
print(reg_lin_shoe.coef_)
print(intercept_shoe)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

# Plot the first line graph on the first subplot
ax1.scatter(demo_perso["Shoe size"], demo_perso["Height (in cm)"])
ax1.plot(demo_perso["Shoe size"], intercept_shoe + reg_lin_shoe.coef_*demo_perso["Shoe size"], color = "red")
ax1.set_xlabel('Shoe Size')
ax1.set_ylabel('Height (in cm)')
ax1.set_title('Regression Shoe Size & Height')
ax1.set_ylim(140,210)


# Plot the second line graph on the second subplot
ax2.scatter(demo_perso["Weight (in kg)"], demo_perso["Height (in cm)"])
ax2.plot(demo_perso["Weight (in kg)"], intercept_weight + reg_lin_weight.coef_*demo_perso["Weight (in kg)"], color = "red")
ax2.set_xlabel('Weight')
ax2.set_ylabel('Height (in cm)')
ax2.set_title('Regression Weight & Height')
ax2.set_ylim(140,210)


plt.tight_layout()

plt.show()
# Out:
# 0.7898408272863814
# [0.69]
# 125.7143292319387
# 0.7640584023409857
# [2.8]
# 153.34343434343435
