# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
inpPath = "C:/CarolineZiegler/Studium_DCU/8. Semester/Data Analytics for Marketing Applications/Pair Assignments/Assignment 2/"
apples = pd.read_csv(inpPath + "apple_quality.csv", delimiter =  ",", header = 0)
apples
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 9 columns]

# %%
apples = apples.drop(4000)
apples
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# 3      0.790723217    good
# 4      0.501984036    good
# ...            ...     ...
# 3995   0.137784369     bad
# 3996   1.854235285    good
# 3997  -1.334611391     bad
# 3998  -2.229719806    good
# 3999   1.599796456    good
#
# [4000 rows x 9 columns]

# %%
apples.drop("A_id", axis=1, inplace = True)
apples
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# 3      0.790723217    good
# 4      0.501984036    good
# ...            ...     ...
# 3995   0.137784369     bad
# 3996   1.854235285    good
# 3997  -1.334611391     bad
# 3998  -2.229719806    good
# 3999   1.599796456    good
#
# [4000 rows x 8 columns]

# %%
apples.describe().style.background_gradient(axis=1, cmap='Blues')
# Out:
# <style type="text/css">
# #T_d04cb_row0_col0, #T_d04cb_row0_col1, #T_d04cb_row0_col2, #T_d04cb_row0_col3, #T_d04cb_row0_col4, #T_d04cb_row0_col5, #T_d04cb_row1_col1, #T_d04cb_row2_col3, #T_d04cb_row3_col0, #T_d04cb_row3_col1, #T_d04cb_row4_col1, #T_d04cb_row5_col1, #T_d04cb_row6_col1, #T_d04cb_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d04cb_row1_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_d04cb_row1_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_d04cb_row1_col3, #T_d04cb_row2_col2, #T_d04cb_row3_col5, #T_d04cb_row4_col3, #T_d04cb_row5_col3, #T_d04cb_row6_col3, #T_d04cb_row7_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d04cb_row1_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_d04cb_row1_col5, #T_d04cb_row5_col5 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_d04cb_row2_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_d04cb_row2_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_d04cb_row2_col4 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_d04cb_row2_col5 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_d04cb_row3_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_d04cb_row3_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_d04cb_row3_col4 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_d04cb_row4_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_d04cb_row4_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_d04cb_row4_col4 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_d04cb_row4_col5 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_d04cb_row5_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_d04cb_row5_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_d04cb_row5_col4 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_d04cb_row6_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_d04cb_row6_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_d04cb_row6_col4 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_d04cb_row6_col5 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_d04cb_row7_col0 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_d04cb_row7_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_d04cb_row7_col4 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_d04cb_row7_col5 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d04cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d04cb_level0_col0" class="col_heading level0 col0" >Size</th>
#       <th id="T_d04cb_level0_col1" class="col_heading level0 col1" >Weight</th>
#       <th id="T_d04cb_level0_col2" class="col_heading level0 col2" >Sweetness</th>
#       <th id="T_d04cb_level0_col3" class="col_heading level0 col3" >Crunchiness</th>
#       <th id="T_d04cb_level0_col4" class="col_heading level0 col4" >Juiciness</th>
#       <th id="T_d04cb_level0_col5" class="col_heading level0 col5" >Ripeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d04cb_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_d04cb_row0_col0" class="data row0 col0" >4000.000000</td>
#       <td id="T_d04cb_row0_col1" class="data row0 col1" >4000.000000</td>
#       <td id="T_d04cb_row0_col2" class="data row0 col2" >4000.000000</td>
#       <td id="T_d04cb_row0_col3" class="data row0 col3" >4000.000000</td>
#       <td id="T_d04cb_row0_col4" class="data row0 col4" >4000.000000</td>
#       <td id="T_d04cb_row0_col5" class="data row0 col5" >4000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d04cb_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_d04cb_row1_col0" class="data row1 col0" >-0.503015</td>
#       <td id="T_d04cb_row1_col1" class="data row1 col1" >-0.989547</td>
#       <td id="T_d04cb_row1_col2" class="data row1 col2" >-0.470479</td>
#       <td id="T_d04cb_row1_col3" class="data row1 col3" >0.985478</td>
#       <td id="T_d04cb_row1_col4" class="data row1 col4" >0.512118</td>
#       <td id="T_d04cb_row1_col5" class="data row1 col5" >0.498277</td>
#     </tr>
#     <tr>
#       <th id="T_d04cb_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_d04cb_row2_col0" class="data row2 col0" >1.928059</td>
#       <td id="T_d04cb_row2_col1" class="data row2 col1" >1.602507</td>
#       <td id="T_d04cb_row2_col2" class="data row2 col2" >1.943441</td>
#       <td id="T_d04cb_row2_col3" class="data row2 col3" >1.402757</td>
#       <td id="T_d04cb_row2_col4" class="data row2 col4" >1.930286</td>
#       <td id="T_d04cb_row2_col5" class="data row2 col5" >1.874427</td>
#     </tr>
#     <tr>
#       <th id="T_d04cb_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_d04cb_row3_col0" class="data row3 col0" >-7.151703</td>
#       <td id="T_d04cb_row3_col1" class="data row3 col1" >-7.149848</td>
#       <td id="T_d04cb_row3_col2" class="data row3 col2" >-6.894485</td>
#       <td id="T_d04cb_row3_col3" class="data row3 col3" >-6.055058</td>
#       <td id="T_d04cb_row3_col4" class="data row3 col4" >-5.961897</td>
#       <td id="T_d04cb_row3_col5" class="data row3 col5" >-5.864599</td>
#     </tr>
#     <tr>
#       <th id="T_d04cb_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_d04cb_row4_col0" class="data row4 col0" >-1.816765</td>
#       <td id="T_d04cb_row4_col1" class="data row4 col1" >-2.011770</td>
#       <td id="T_d04cb_row4_col2" class="data row4 col2" >-1.738425</td>
#       <td id="T_d04cb_row4_col3" class="data row4 col3" >0.062764</td>
#       <td id="T_d04cb_row4_col4" class="data row4 col4" >-0.801286</td>
#       <td id="T_d04cb_row4_col5" class="data row4 col5" >-0.771677</td>
#     </tr>
#     <tr>
#       <th id="T_d04cb_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_d04cb_row5_col0" class="data row5 col0" >-0.513703</td>
#       <td id="T_d04cb_row5_col1" class="data row5 col1" >-0.984736</td>
#       <td id="T_d04cb_row5_col2" class="data row5 col2" >-0.504758</td>
#       <td id="T_d04cb_row5_col3" class="data row5 col3" >0.998249</td>
#       <td id="T_d04cb_row5_col4" class="data row5 col4" >0.534219</td>
#       <td id="T_d04cb_row5_col5" class="data row5 col5" >0.503445</td>
#     </tr>
#     <tr>
#       <th id="T_d04cb_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_d04cb_row6_col0" class="data row6 col0" >0.805526</td>
#       <td id="T_d04cb_row6_col1" class="data row6 col1" >0.030976</td>
#       <td id="T_d04cb_row6_col2" class="data row6 col2" >0.801922</td>
#       <td id="T_d04cb_row6_col3" class="data row6 col3" >1.894234</td>
#       <td id="T_d04cb_row6_col4" class="data row6 col4" >1.835976</td>
#       <td id="T_d04cb_row6_col5" class="data row6 col5" >1.766212</td>
#     </tr>
#     <tr>
#       <th id="T_d04cb_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_d04cb_row7_col0" class="data row7 col0" >6.406367</td>
#       <td id="T_d04cb_row7_col1" class="data row7 col1" >5.790714</td>
#       <td id="T_d04cb_row7_col2" class="data row7 col2" >6.374916</td>
#       <td id="T_d04cb_row7_col3" class="data row7 col3" >7.619852</td>
#       <td id="T_d04cb_row7_col4" class="data row7 col4" >7.364403</td>
#       <td id="T_d04cb_row7_col5" class="data row7 col5" >7.237837</td>
#     </tr>
#   </tbody>
# </table>

# %%
type(apples.iloc[0,6])
# Out:
# str

# %%
apples["Acidity"] = apples["Acidity"].astype("float")
type(apples.iloc[0,6])
# Out:
# numpy.float64

# %%
apples.describe().style.background_gradient(axis=1, cmap='Blues')
# Out:
# <style type="text/css">
# #T_4b936_row0_col0, #T_4b936_row0_col1, #T_4b936_row0_col2, #T_4b936_row0_col3, #T_4b936_row0_col4, #T_4b936_row0_col5, #T_4b936_row0_col6, #T_4b936_row0_col7, #T_4b936_row0_col8, #T_4b936_row1_col1, #T_4b936_row2_col7, #T_4b936_row3_col0, #T_4b936_row3_col1, #T_4b936_row4_col1, #T_4b936_row5_col1, #T_4b936_row6_col1, #T_4b936_row7_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4b936_row1_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_4b936_row1_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_4b936_row1_col3, #T_4b936_row1_col8, #T_4b936_row2_col6, #T_4b936_row3_col7, #T_4b936_row3_col8, #T_4b936_row4_col3, #T_4b936_row5_col3, #T_4b936_row5_col7, #T_4b936_row5_col8, #T_4b936_row6_col8, #T_4b936_row7_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4b936_row1_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_4b936_row1_col5, #T_4b936_row6_col6 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_4b936_row1_col6 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_4b936_row1_col7 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_4b936_row2_col0, #T_4b936_row2_col4 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_4b936_row2_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_4b936_row2_col2 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_4b936_row2_col3 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_4b936_row2_col5 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_4b936_row2_col8 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_4b936_row3_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_4b936_row3_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_4b936_row3_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_4b936_row3_col5 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_4b936_row3_col6 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_4b936_row4_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_4b936_row4_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_4b936_row4_col4 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_4b936_row4_col5 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_4b936_row4_col6 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_4b936_row4_col7, #T_4b936_row4_col8 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_4b936_row5_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_4b936_row5_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_4b936_row5_col4 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_4b936_row5_col5 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_4b936_row5_col6 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_4b936_row6_col0, #T_4b936_row6_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_4b936_row6_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_4b936_row6_col4 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_4b936_row6_col5 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_4b936_row6_col7 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_4b936_row7_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_4b936_row7_col1 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_4b936_row7_col2 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_4b936_row7_col4 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_4b936_row7_col5 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_4b936_row7_col6 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_4b936_row7_col8 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# </style>
# <table id="T_4b936">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b936_level0_col0" class="col_heading level0 col0" >Size</th>
#       <th id="T_4b936_level0_col1" class="col_heading level0 col1" >Weight</th>
#       <th id="T_4b936_level0_col2" class="col_heading level0 col2" >Sweetness</th>
#       <th id="T_4b936_level0_col3" class="col_heading level0 col3" >Crunchiness</th>
#       <th id="T_4b936_level0_col4" class="col_heading level0 col4" >Juiciness</th>
#       <th id="T_4b936_level0_col5" class="col_heading level0 col5" >Ripeness</th>
#       <th id="T_4b936_level0_col6" class="col_heading level0 col6" >Acidity</th>
#       <th id="T_4b936_level0_col7" class="col_heading level0 col7" >Quality_numeric</th>
#       <th id="T_4b936_level0_col8" class="col_heading level0 col8" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b936_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_4b936_row0_col0" class="data row0 col0" >4000.000000</td>
#       <td id="T_4b936_row0_col1" class="data row0 col1" >4000.000000</td>
#       <td id="T_4b936_row0_col2" class="data row0 col2" >4000.000000</td>
#       <td id="T_4b936_row0_col3" class="data row0 col3" >4000.000000</td>
#       <td id="T_4b936_row0_col4" class="data row0 col4" >4000.000000</td>
#       <td id="T_4b936_row0_col5" class="data row0 col5" >4000.000000</td>
#       <td id="T_4b936_row0_col6" class="data row0 col6" >4000.000000</td>
#       <td id="T_4b936_row0_col7" class="data row0 col7" >4000.000000</td>
#       <td id="T_4b936_row0_col8" class="data row0 col8" >4000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4b936_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_4b936_row1_col0" class="data row1 col0" >-0.503015</td>
#       <td id="T_4b936_row1_col1" class="data row1 col1" >-0.989547</td>
#       <td id="T_4b936_row1_col2" class="data row1 col2" >-0.470479</td>
#       <td id="T_4b936_row1_col3" class="data row1 col3" >0.985478</td>
#       <td id="T_4b936_row1_col4" class="data row1 col4" >0.512118</td>
#       <td id="T_4b936_row1_col5" class="data row1 col5" >0.498277</td>
#       <td id="T_4b936_row1_col6" class="data row1 col6" >0.076877</td>
#       <td id="T_4b936_row1_col7" class="data row1 col7" >0.501000</td>
#       <td id="T_4b936_row1_col8" class="data row1 col8" >0.986500</td>
#     </tr>
#     <tr>
#       <th id="T_4b936_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_4b936_row2_col0" class="data row2 col0" >1.928059</td>
#       <td id="T_4b936_row2_col1" class="data row2 col1" >1.602507</td>
#       <td id="T_4b936_row2_col2" class="data row2 col2" >1.943441</td>
#       <td id="T_4b936_row2_col3" class="data row2 col3" >1.402757</td>
#       <td id="T_4b936_row2_col4" class="data row2 col4" >1.930286</td>
#       <td id="T_4b936_row2_col5" class="data row2 col5" >1.874427</td>
#       <td id="T_4b936_row2_col6" class="data row2 col6" >2.110270</td>
#       <td id="T_4b936_row2_col7" class="data row2 col7" >0.500062</td>
#       <td id="T_4b936_row2_col8" class="data row2 col8" >0.779082</td>
#     </tr>
#     <tr>
#       <th id="T_4b936_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_4b936_row3_col0" class="data row3 col0" >-7.151703</td>
#       <td id="T_4b936_row3_col1" class="data row3 col1" >-7.149848</td>
#       <td id="T_4b936_row3_col2" class="data row3 col2" >-6.894485</td>
#       <td id="T_4b936_row3_col3" class="data row3 col3" >-6.055058</td>
#       <td id="T_4b936_row3_col4" class="data row3 col4" >-5.961897</td>
#       <td id="T_4b936_row3_col5" class="data row3 col5" >-5.864599</td>
#       <td id="T_4b936_row3_col6" class="data row3 col6" >-7.010538</td>
#       <td id="T_4b936_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_4b936_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4b936_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_4b936_row4_col0" class="data row4 col0" >-1.816765</td>
#       <td id="T_4b936_row4_col1" class="data row4 col1" >-2.011770</td>
#       <td id="T_4b936_row4_col2" class="data row4 col2" >-1.738425</td>
#       <td id="T_4b936_row4_col3" class="data row4 col3" >0.062764</td>
#       <td id="T_4b936_row4_col4" class="data row4 col4" >-0.801286</td>
#       <td id="T_4b936_row4_col5" class="data row4 col5" >-0.771677</td>
#       <td id="T_4b936_row4_col6" class="data row4 col6" >-1.377424</td>

# %%
apples.isna().sum()
# Out:
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
sns.histplot(apples["Size"])
plt.show()

# %%
print(apples["Size"].skew())
print(apples["Size"].kurtosis())
# Out:
# -0.0024369433916124265
# -0.08334065839772187

# %%
sns.histplot(apples["Weight"])
plt.show()

# %%
print(apples["Weight"].skew())
print(apples["Weight"].kurtosis())
# Out:
# 0.003101570142725525
# 0.3590498289188946

# %%
sns.histplot(apples["Sweetness"])
plt.show()

# %%
print(apples["Sweetness"].skew())
print(apples["Sweetness"].kurtosis())
# Out:
# 0.08384979089728131
# 0.014472224432848346

# %%
sns.histplot(apples["Crunchiness"])
plt.show()

# %%
print(apples["Crunchiness"].skew())
print(apples["Crunchiness"].kurtosis())
# Out:
# 0.00023010591402162201
# 0.7220204828975696

# %%
sns.histplot(apples["Juiciness"])
plt.show()

# %%
print(apples["Juiciness"].skew())
print(apples["Juiciness"].kurtosis())
# Out:
# -0.11342083348577094
# 0.02873539531153213

# %%
sns.histplot(apples["Ripeness"])
plt.show()

# %%
print(apples["Ripeness"].skew())
print(apples["Ripeness"].kurtosis())
# Out:
# -0.008764097369532927
# -0.07185020249958196

# %%
sns.histplot(apples["Acidity"])
plt.show()

# %%
print(apples["Acidity"].skew())
print(apples["Acidity"].kurtosis())
# Out:
# 0.05578345335267586
# -0.09345141613095986

# %%
#gettig an overview over all histograms understanding normal distribution
numerical_columns = ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity']

plt.figure(figsize=(15, 10))
sns.set_palette("tab10")


for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 3, i)
    sns.histplot(data=apples, x=column, kde=True, bins=20)  
    plt.title(column)

plt.tight_layout()
plt.show()

# %%
apples["Quality"].unique()
# Out:
# array(['good', 'bad'], dtype=object)

# %%
quality_counts = apples["Quality"].value_counts()

plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%', textprops={'fontsize':10})
plt.title('Quality Distribution')
plt.show()

# %%
encoded_dict = {'good': 1, 'bad': 0}
apples["Quality_numeric"] = apples["Quality"].map(encoded_dict)
apples
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity Quality  Quality_numeric
# 0    -0.491590    good                1
# 1    -0.722809    good                1
# 2     2.621636     bad                0
# 3     0.790723    good                1
# 4     0.501984    good                1
# ...        ...     ...              ...
# 3995  0.137784     bad                0
# 3996  1.854235    good                1
# 3997 -1.334611     bad                0
# 3998 -2.229720    good                1
# 3999  1.599796    good                1
#
# [4000 rows x 9 columns]

# %%
plt.figure(figsize=(15, 10))
sns.set_palette("Set2")

for i, column in enumerate(apples.columns[:-2]):  
    plt.subplot(3, 3, i + 1)
    sns.boxplot(x='Quality_numeric', y=column, data=apples)
    plt.title(f'{column} by Quality_numeric')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.set(style="white")  

sns.jointplot(x='Size', y='Weight', hue='Quality_numeric', data=apples, palette='tab10', s=9)

# %%
apples_corr = apples.corr()
apples_corr
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_19336\3231808911.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   apples_corr = apples.corr()
#                      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# Size             1.000000 -0.170702  -0.324680     0.169868  -0.018892
# Weight          -0.170702  1.000000  -0.154246    -0.095882  -0.092263
# Sweetness       -0.324680 -0.154246   1.000000    -0.037552   0.095882
# Crunchiness      0.169868 -0.095882  -0.037552     1.000000  -0.259607
# Juiciness       -0.018892 -0.092263   0.095882    -0.259607   1.000000
# Ripeness        -0.134773 -0.243824  -0.273800    -0.201982  -0.097144
# Acidity          0.196218  0.016414   0.085999     0.069943   0.248714
# Quality_numeric  0.244007  0.001421   0.250998    -0.012376   0.260223
#
#                  Ripeness   Acidity  Quality_numeric
# Size            -0.134773  0.196218         0.244007
# Weight          -0.243824  0.016414         0.001421
# Sweetness       -0.273800  0.085999         0.250998
# Crunchiness     -0.201982  0.069943        -0.012376
# Juiciness       -0.097144  0.248714         0.260223
# Ripeness         1.000000 -0.202669        -0.264315
# Acidity         -0.202669  1.000000        -0.007697
# Quality_numeric -0.264315 -0.007697         1.000000

# %%
sns.heatmap(apples_corr, cmap= "Blues", vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.title('Correlation Heatmap')
plt.show()

# %%
mask = np.triu(np.ones_like(apples_corr, dtype=bool))

plt.figure(figsize=(10, 8))

sns.heatmap(apples_corr, mask=mask, cmap= "Blues", vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.title('Correlation Heatmap')
plt.show()

# %%
#Analysing the correlations pairs with a correlation higher or lower and equal to 0.2 and -0.2
tpllst = []
for i in range(0,8):
    for j in range(0,8):
        if apples_corr.iloc[i,j]>=0.2 and apples_corr.iloc[i,j]<1: 
            tpllst.append((apples_corr.index[i], apples_corr.index[j], apples_corr.iloc[i,j]))
        elif apples_corr.iloc[i,j]<= -0.2 and apples_corr.iloc[i,j]>-1:
            tpllst.append((apples_corr.index[i], apples_corr.index[j], apples_corr.iloc[i,j]))

dltlst = [] #new list to save only those items where the quality_numeric is not at the second place underlining that this variable makes no sense as independent variable
for i in range(len(tpllst)):
    if tpllst[i][1] != "Quality_numeric":
        dltlst.append(tpllst[i])
dltlst
# Out:
# [('Size', 'Sweetness', -0.32468024956214525),
#  ('Weight', 'Ripeness', -0.24382426555524034),
#  ('Sweetness', 'Size', -0.32468024956214525),
#  ('Sweetness', 'Ripeness', -0.27380006756070097),
#  ('Crunchiness', 'Juiciness', -0.2596070855403657),
#  ('Crunchiness', 'Ripeness', -0.2019816301087344),
#  ('Juiciness', 'Crunchiness', -0.2596070855403657),
#  ('Juiciness', 'Acidity', 0.24871388355218035),
#  ('Ripeness', 'Weight', -0.24382426555524034),
#  ('Ripeness', 'Sweetness', -0.27380006756070097),
#  ('Ripeness', 'Crunchiness', -0.2019816301087344),
#  ('Ripeness', 'Acidity', -0.20266908286974356),
#  ('Acidity', 'Juiciness', 0.24871388355218035),
#  ('Acidity', 'Ripeness', -0.20266908286974356),
#  ('Quality_numeric', 'Size', 0.24400717867851435),
#  ('Quality_numeric', 'Sweetness', 0.250998458836519),
#  ('Quality_numeric', 'Juiciness', 0.26022254529522404),
#  ('Quality_numeric', 'Ripeness', -0.264314879245958)]

# %%
#linear regressions for variables with 2 or more correlations above/equal 0.2 or below/equal -0.2

# import libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = apples[['Size','Ripeness']]
yDf = apples['Sweetness']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin_sweet = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin_sweet.score(X_test, y_test))
print(reg_lin_sweet.coef_)
# Out:
# 0.21798845545811663
# [-0.37174626 -0.33195112]

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = apples[['Juiciness','Ripeness']]
yDf = apples['Crunchiness']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin_crunch = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin_crunch.score(X_test, y_test))
print(reg_lin_crunch.coef_)
# Out:
# 0.12144955343954655
# [-0.20951494 -0.16272031]

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = apples[['Weight','Sweetness', 'Crunchiness', 'Acidity']]
yDf = apples['Ripeness']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin_ripe = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin_ripe.score(X_test, y_test))
print(reg_lin_ripe.coef_)
# Out:
# 0.25431383747463787
# [-0.37578184 -0.30490986 -0.30561386 -0.14214598]

# %%
# Split the data columnwise into the independt variables (x) and the dependent variable (y)
xDf = apples[['Juiciness','Ripeness']]
yDf = apples['Acidity']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

#fitting the model
reg_lin_ripe = LinearRegression().fit(X_train, y_train)

#getting the accuracy
print(reg_lin_ripe.score(X_test, y_test))
print(reg_lin_ripe.coef_)
# Out:
# 0.08352516796723763
# [ 0.26450021 -0.19398186]

# %%
from sklearn.linear_model import LogisticRegression
xDf = apples[['Size','Sweetness','Juiciness','Ripeness']]
yDf = apples['Quality_numeric']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

logreg = LogisticRegression()

# Fit the model to the training data
logreg.fit(X_train, y_train)


# Evaluate the accuracy of the model
print(logreg.score(X_test, y_test))
# Out:
# 0.69

# %%
# Access the coefficient values
coefficients = logreg.coef_

# Calculate the odds ratios
odds_ratios = np.exp(coefficients)

print("Shape of odds_ratios:", odds_ratios.shape)
print("Number of columns in apples[['Size','Sweetness','Juiciness','Ripeness']]:", len(apples[['Size',
                                                                                               'Sweetness',
                                                                                               'Juiciness',
                                                                                               'Ripeness']].columns))

# Iterate over the independent variables and their odds ratios
for i, feature in enumerate(apples[['Size','Sweetness','Juiciness','Ripeness']].columns):
    print(f"{feature}: Odds Ratio = {odds_ratios[0, i]}")
# Out:
# Shape of odds_ratios: (1, 4)
# Number of columns in apples[['Size','Sweetness','Juiciness','Ripeness']]: 4
# Size: Odds Ratio = 1.641179757868467
# Sweetness: Odds Ratio = 1.583372499474963
# Juiciness: Odds Ratio = 1.4064959535244186
# Ripeness: Odds Ratio = 0.8351152188063102

# %%
xDf = apples[['Size']]
yDf = apples['Quality_numeric']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

logreg = LogisticRegression()

# Fit the model to the training data
logreg.fit(X_train, y_train)


# Evaluate the accuracy of the model
print(logreg.score(X_test, y_test))
# Out:
# 0.605

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=apples['Size'], y=apples['Quality_numeric'], color='blue', label='Data Points')

# Plot logistic function
x_values = np.linspace(xDf.min(), xDf.max(), 100).reshape(-1, 1)
y_proba = logreg.predict_proba(x_values)[:, 1]  # Probability of class 1
plt.plot(x_values, y_proba, color='red', label='Logistic Function')

plt.xlabel('Feature')
plt.ylabel('Probability')
plt.title('Logistic Regression')
plt.legend()
plt.show()
# Out:
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import random

random.seed(42)

#optional
xDf = apples.drop(columns='Quality')
#correct import
from sklearn.cluster import KMeans

#initialize inertia list and get the k and the inertia per k (or WCSS per k)
inertiaLst = []
for kVal in range(1, 10):
    kmeans = KMeans(n_clusters=kVal)
    kmeans.fit(xDf)
    inertiaLst.append([kVal, kmeans.inertia_])

#transposing and plotting the inertia list
inertiaArr = np.array(inertiaLst).transpose()
plt.plot(inertiaArr[0], inertiaArr[1])
plt.xlabel('k')
plt.ylabel('Inertia')
plt.show()
# Out:
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#read kVal at the "elbow"
kVal = 3

#set the k for the KMeans to kVal
kmeans = KMeans(n_clusters=kVal)

#fit the model
kmeans.fit(xDf)

#get the label from the kmeans and add it as a column to the df
apples['label'] = kmeans.labels_
# Out:
# C:\Users\CZ\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
apples
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity Quality  Quality_numeric  label
# 0    -0.491590    good                1      2
# 1    -0.722809    good                1      2
# 2     2.621636     bad                0      0
# 3     0.790723    good                1      0
# 4     0.501984    good                1      0
# ...        ...     ...              ...    ...
# 3995  0.137784     bad                0      1
# 3996  1.854235    good                1      0
# 3997 -1.334611     bad                0      1
# 3998 -2.229720    good                1      2
# 3999  1.599796    good                1      0
#
# [4000 rows x 10 columns]

# %%
line_colors = ['blue','green', 'gray'] 
label_counts = apples["label"].value_counts()

plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', textprops={'fontsize':10}, colors = line_colors)
plt.title('Label Distribution')
plt.show()

# %%
label_counts
# Out:
# 1    1572
# 0    1241
# 2    1187
# Name: label, dtype: int64

# %%
apples.drop(columns = "Quality").groupby(by = "label").mean()
# Out:
#            Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# label
# 0      0.393227 -1.061550  -0.311425     0.953723   1.623771 -0.754048
# 1     -0.017902 -0.932814  -1.818188     1.224925  -0.696652  1.320929
# 2     -2.082487 -0.989401   1.148067     0.701567   0.950724  0.718099
#
#         Acidity  Quality_numeric
# label
# 0      2.111096         0.614827
# 1     -0.709724         0.325064
# 2     -1.008151         0.614996

# %%
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[ 0.3994883  -1.06087439 -0.31465228  0.95336606  1.62516799 -0.75549405
#    2.1089665   0.61581921]
#  [-0.01696957 -0.93399311 -1.81602336  1.22532892 -0.69796081  1.31704442
#   -0.71282752  0.32485696]
#  [-2.08782104 -0.9887135   1.14860676  0.70138778  0.95351944  0.72176428
#   -0.99682038  0.61447811]]

# %%
centroids = kmeans.cluster_centers_
feature_names = ['Size', 'Weight', 'Sweetness' , 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity' ,'Quality_numeric']

# Create a DataFrame to store the centroids and feature names
centroid_table = pd.DataFrame(centroids, columns=feature_names)

centroid_table
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness   Acidity  \
# 0  0.399488 -1.060874  -0.314652     0.953366   1.625168 -0.755494  2.108966
# 1 -0.016970 -0.933993  -1.816023     1.225329  -0.697961  1.317044 -0.712828
# 2 -2.087821 -0.988714   1.148607     0.701388   0.953519  0.721764 -0.996820
#
#    Quality_numeric
# 0         0.615819
# 1         0.324857
# 2         0.614478

# %%
transposed_centroid = centroid_table.transpose()
transposed_centroid
# Out:
#                         0         1         2
# Size             0.399488 -0.016970 -2.087821
# Weight          -1.060874 -0.933993 -0.988714
# Sweetness       -0.314652 -1.816023  1.148607
# Crunchiness      0.953366  1.225329  0.701388
# Juiciness        1.625168 -0.697961  0.953519
# Ripeness        -0.755494  1.317044  0.721764
# Acidity          2.108966 -0.712828 -0.996820
# Quality_numeric  0.615819  0.324857  0.614478

# %%
line_colors = ['gray', 'green', 'blue'] 
fig = plt.figure(figsize=(12, 8))
for i, column in enumerate(transposed_centroid.columns):
    plt.plot(transposed_centroid[column], marker='o', linestyle='', markersize=12, color=line_colors[i])
plt.title('Characteristics for each Apple Variety', fontweight='bold')
plt.xlabel("Features", fontweight='bold')
plt.ylabel("Centroid Value", fontweight='bold')
plt.legend(transposed_centroid.columns)

# %%
plt.figure(figsize=(15, 10))
sns.set(style="white") 

sns.jointplot(x='Sweetness', y='Juiciness', hue='label', data=apples, palette=line_colors, s=9)

# %%
plt.figure(figsize=(15, 10))
sns.set(style="white") 

sns.jointplot(x='Sweetness', y='Ripeness', hue='label', data=apples, palette=line_colors, s=9)

# %%
plt.figure(figsize=(15, 10))
sns.set(style="white") 

sns.jointplot(x='Sweetness', y='Acidity', hue='label', data=apples, palette=line_colors, s=9)

# %%
plt.figure(figsize=(15, 10))
sns.set(style="white") 

sns.jointplot(x='Juiciness', y='Ripeness', hue='label', data=apples, palette=line_colors, s=9)

# %%
plt.figure(figsize=(15, 10))
sns.set(style="white") 

sns.jointplot(x='Juiciness', y='Acidity', hue='label', data=apples, palette=line_colors, s=9)

# %%
plt.figure(figsize=(15, 10))
sns.set(style="white") 

sns.jointplot(x='Ripeness', y='Acidity', hue='label', data=apples, palette=line_colors, s=9)

# %%
apples_0 = apples[apples["label"] == 0]
apples_0
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 6     1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
# 17   -0.074370 -4.714750   0.249768     2.935319   1.409755 -2.643810
# ...        ...       ...        ...          ...        ...       ...
# 3969  3.300382 -1.662606  -1.724308    -0.074672   3.088414  0.720912
# 3976 -0.524415  0.897921  -1.377694     1.579954   0.994690 -0.824029
# 3985 -0.230550 -0.669956  -1.896049     0.657545   1.843634  0.473194
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity Quality  Quality_numeric  label
# 2     2.621636     bad                0      0
# 3     0.790723    good                1      0
# 4     0.501984    good                1      0
# 6     2.414171    good                1      0
# 17    1.250970    good                1      0
# ...        ...     ...              ...    ...
# 3969  2.870162    good                1      0
# 3976  2.422747     bad                0      0
# 3985  1.461085     bad                0      0
# 3996  1.854235    good                1      0
# 3999  1.599796    good                1      0
#
# [1241 rows x 10 columns]

# %%
apples_1 = apples[apples["label"] == 1]
apples_1
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 5    -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 9    -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
# 11    2.450960 -0.564177  -1.635041     0.942400  -2.087317  1.214322
# 12   -0.170812 -1.867271  -1.771845     2.413155  -3.094555 -0.624884
# 14    2.839581 -0.344798  -1.019797     0.894581  -1.300061  0.582379
# ...        ...       ...        ...          ...        ...       ...
# 3992  1.764253 -2.079695  -0.083383    -0.086724  -1.703385  3.840101
# 3993  1.520142 -0.352623  -3.206467     1.341719   0.675568  0.107093
# 3994  1.482508 -2.581181  -0.306888     1.527877   1.056361  2.560829
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
#
#        Acidity Quality  Quality_numeric  label
# 5    -2.981523     bad                0      1
# 9     2.185608     bad                0      1
# 11    1.294324    good                1      1
# 12   -2.076114     bad                0      1
# 14    1.709708    good                1      1
# ...        ...     ...              ...    ...
# 3992 -0.338261    good                1      1
# 3993 -0.945080     bad                0      1
# 3994 -1.229255    good                1      1
# 3995  0.137784     bad                0      1
# 3997 -1.334611     bad                0      1
#
# [1572 rows x 10 columns]

# %%
apples_2 = apples[apples["label"] == 2]
apples_2
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 7    -1.995462 -0.428958   1.530644    -0.742972   0.158834  0.974438
# 8    -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 10   -2.699336 -1.329507  -1.418507    -0.625546   2.371074  3.403165
# ...        ...       ...        ...          ...        ...       ...
# 3982 -2.434450  0.280785   0.426244     0.924208   1.439966  0.517793
# 3983 -3.652936 -1.117509   3.271792    -1.266320   2.360319  0.007212
# 3987 -4.035850 -1.301354   1.367232     0.887992   1.464440  1.608556
# 3991 -4.007762  2.970164   0.218167    -0.492369   1.656375 -2.133895
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
#
#        Acidity Quality  Quality_numeric  label
# 0    -0.491590    good                1      2
# 1    -0.722809    good                1      2
# 7    -1.470125    good                1      2
# 8    -4.871905     bad                0      2
# 10   -2.810808     bad                0      2
# ...        ...     ...              ...    ...
# 3982 -2.334245    good                1      2
# 3983 -2.022186    good                1      2
# 3987  1.220320     bad                0      2
# 3991 -4.431321    good                1      2
# 3998 -2.229720    good                1      2
#
# [1187 rows x 10 columns]

# %%
from scipy import stats

# %%
# Sample data
sweet_1 = apples_1["Sweetness"]
sweet_2 = apples_2["Sweetness"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(sweet_2, sweet_1)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 50.538669333001174
# p-value: 0.0

# %%
# Sample data
juicy_1 = apples_1["Juiciness"]
juicy_0 = apples_0["Juiciness"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(juicy_0, juicy_1)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 35.75720300718228
# p-value: 3.8856632483382766e-231

# %%
# Sample data
ripe_1 = apples_1["Ripeness"]
ripe_0 = apples_0["Ripeness"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(ripe_1, ripe_0)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 31.960895467786422
# p-value: 1.7951131705735534e-191

# %%
# Sample data
acid_2 = apples_2["Acidity"]
acid_0 = apples_0["Acidity"]

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(acid_0, acid_2)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 46.527830256376006
# p-value: 0.0

# %%
#Besides just including 4 independent variables, all features were included leading to a even higher significance
from sklearn.linear_model import LogisticRegression
xDf = apples[['Size','Sweetness','Juiciness','Ripeness', 'Weight', 'Acidity', 'Crunchiness']]
yDf = apples['Quality_numeric']

# Split between train and test set
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

logreg2 = LogisticRegression()

# Fit the model to the training data
logreg2.fit(X_train, y_train)


# Evaluate the accuracy of the model
print(logreg2.score(X_test, y_test))
print(logreg2.coef_)
# Out:
# 0.7275
# [[ 0.65733981  0.59473852  0.46334712 -0.13444247  0.26102701 -0.2786047
#    0.05296088]]

# %%
#instead of manually entering the clusters max and min values another code was created which is replicable 
#for other projects as well
sweet_max = centroid_table['Sweetness'].idxmax()
sweet_min = centroid_table['Sweetness'].idxmin()

if sweet_max == 0:
    sweet_max_df = apples_0['Sweetness']
elif sweet_max == 1:
    sweet_max_df = apples_1['Sweetness']
elif sweet_max == 2:
    sweet_max_df = apples_2['Sweetness']
    

if sweet_min == 0:
    sweet_min_df = apples_0['Sweetness']
elif sweet_min == 1:
    sweet_min_df = apples_1['Sweetness']
elif sweet_min == 2:
    sweet_min_df = apples_2['Sweetness']

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(sweet_max_df, sweet_min_df)

# Print the results
print(f'Test: Is Apple Variaty {sweet_max} systematically more sweet than Apple Variaty {sweet_min}?' )
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# Test: Is Apple Variaty 2 systematically more sweet than Apple Variaty 1?
# t-statistic: 50.538669333001174
# p-value: 0.0

# %%
juicy_max = centroid_table['Juiciness'].idxmax()
juicy_min = centroid_table['Juiciness'].idxmin()

if juicy_max == 0:
    juicy_max_df = apples_0['Juiciness']
elif juicy_max == 1:
    juicy_max_df = apples_1['Juiciness']
elif juicy_max == 2:
    juicy_max_df = apples_2['Juiciness']
    

if juicy_min == 0:
    juicy_min_df = apples_0['Juiciness']
elif juicy_min == 1:
    juicy_min_df = apples_1['Juiciness']
elif juicy_min == 2:
    juicy_min_df = apples_2['Juiciness']

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(juicy_max_df, juicy_min_df)

# Print the results
print(f'Test: Is Apple Variaty {juicy_max} systematically more juicy than Apple Variaty {juicy_min}?' )
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# Test: Is Apple Variaty 0 systematically more juicy than Apple Variaty 1?
# t-statistic: 35.75720300718228
# p-value: 3.8856632483382766e-231

# %%
ripe_max = centroid_table['Ripeness'].idxmax()
ripe_min = centroid_table['Ripeness'].idxmin()

if ripe_max == 0:
    ripe_max_df = apples_0['Ripeness']
elif ripe_max == 1:
    ripe_max_df = apples_1['Ripeness']
elif ripe_max == 2:
    ripe_max_df = apples_2['Ripeness']
    

if ripe_min == 0:
    ripe_min_df = apples_0['Ripeness']
elif ripe_min == 1:
    ripe_min_df = apples_1['Ripeness']
elif ripe_min == 2:
    ripe_min_df = apples_2['Ripeness']

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(ripe_max_df, ripe_min_df)

# Print the results
print(f'Test: Is Apple Variaty {ripe_max} systematically more ripe than Apple Variaty {ripe_min}?' )
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# Test: Is Apple Variaty 1 systematically more ripe than Apple Variaty 0?
# t-statistic: 31.960895467786422
# p-value: 1.7951131705735534e-191

# %%
acid_max = centroid_table['Acidity'].idxmax()
acid_min = centroid_table['Acidity'].idxmin()

if acid_max == 0:
    acid_max_df = apples_0['Acidity']
elif acid_max == 1:
    acid_max_df = apples_1['Acidity']
elif acid_max == 2:
    acid_max_df = apples_2['Acidity']
    

if acid_min == 0:
    acid_min_df = apples_0['Acidity']
elif acid_min == 1:
    acid_min_df = apples_1['Acidity']
elif acid_min == 2:
    acid_min_df = apples_2['Acidity']

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(acid_max_df, acid_min_df)

# Print the results
print(f'Test: Have Apples from Variaty {acid_max} systematically more Acidity than Apples from Variaty {acid_min}?' )
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# Test: Have Apples from Variaty 0 systematically more Acidity than Apples from Variaty 2?
# t-statistic: 46.527830256376006
# p-value: 0.0
